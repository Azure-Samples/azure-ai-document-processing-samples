# %%
import sys
sys.path.append('../../modules/') # Import local modules

from IPython.display import display, Markdown
import os
import pandas as pd
from dotenv import dotenv_values
import json
from openai import AzureOpenAI
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeResult, DocumentContentFormat
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from concurrent.futures import ThreadPoolExecutor

from samples.app_settings import AppSettings
from samples.utils.stopwatch import Stopwatch
from samples.utils.storage_utils import create_json_file
from samples.models.document_processing_result import DataExtractionResult

from samples.models.invoice import Invoice
from samples.confidence.confidence_utils import merge_confidence_values
from samples.confidence.openai_confidence import evaluate_confidence as evaluate_openai_confidence
from samples.confidence.document_intelligence_confidence import evaluate_confidence as evaluate_di_confidence
from samples.evaluation.accuracy_evaluator import AccuracyEvaluator
from samples.evaluation.comparison import get_extraction_comparison
from samples.utils.custom_json_encoder import CustomJsonEncoder

# %%
# Set the working directory to the root of the repo
working_dir = os.path.abspath('../../../../')
settings = AppSettings(dotenv_values(f"{working_dir}/.env"))
sample_path = f"{working_dir}/samples/python/demo/gp"
sample_name = "document-extraction-prebuilt-invoice"

# Configure the default credential for accessing Azure services using Azure CLI credentials
credential = DefaultAzureCredential(
    exclude_workload_identity_credential=True,
    exclude_developer_cli_credential=True,
    exclude_environment_credential=True,
    exclude_managed_identity_credential=True,
    exclude_powershell_credential=True,
    exclude_shared_token_cache_credential=True,
    exclude_interactive_browser_credential=True
)

endpoint = "https://di-gp-di-weu.cognitiveservices.azure.com/"

document_intelligence_client = DocumentIntelligenceClient(
    endpoint=endpoint,
    credential=credential
)

# %%
path = f"{working_dir}/samples/assets/invoices/"
pdf_fname = 'invoice_6.pdf'
pdf_fpath = f"{path}{pdf_fname}"

# %%
with Stopwatch() as di_stopwatch:
    with open(pdf_fpath, "rb") as f:
        poller = document_intelligence_client.begin_analyze_document(
            model_id="prebuilt-invoice",
            body=f,
            content_type="application/pdf"
        )
    
    result: AnalyzeResult = poller.result()

# %%
result_json = json.dumps(result._data, cls=CustomJsonEncoder, indent=4)

display(Markdown(f"### Document Intelligence Result\nTook {di_stopwatch.elapsed:.2f} seconds"))
print(result_json)
# Out:
# ### Document Intelligence Result
# Took 14.99 seconds
# {
#     "apiVersion": "2024-11-30",
#     "modelId": "prebuilt-invoice",
#     "stringIndexType": "textElements",
#     "content": "NEXGEN\nUnit 4, Innovation Drive\nPhone: +44 (0)1234 567890\nMilton Keynes\ninfo@nexgen.co.uk\nInnovation Drives Progress\nBuckinghamshire\nMK9 1FH\nBILL TO\nSHIP TO\nAlphaTech Solutions\nAlphaTech Solutions\n22 Regent Street\nWarehouse 5, Met Business Park\nLondon\nLeicester\nSWIY 4PD\nLE19 1WD\nInvoice No.\nInvoice Date\nShip Date\nPurchase Order\nCustomer Ref.\nNG-INV-2025-00123\n2025-04-24\n2025-04-19\nPO-556423\nALTEC-SLN\nProduct Code\nDescription\nUnits\nExcl.\nVAT\nIncl. :selected:\n10323\nMAILBOX 25PK\n245\n3787.70\n568.16\n4355.86\n15%\nCOMMENTS\nExpect payment by 6 May!\nREMIT PAYMENT TO\nName: Julia Patel\nNEXGEN\nUnit 4, Innovation Drive\nTR\u00e3o\nMilton Keynes\nBuckinghamshire\nSignature:\nMK9 1FH\n29/4/25\nDate:\n** Please sign and return to info@nexgen.co.uk **\nRecipient has 30 days from date of issue of this invoice to render queries, thereafter all queries will be null and void\nREGULATIONS REQUIRE PAYMENT WITHIN 45 DAYS\nProduct\nLocation\nPer Unit\nUnits\nExcl.\n10323 - Mailbox 25pk\n1011\n15.46\n11\n170.06\n245x 25 = 615 total.\n1012\n15.46\n5\n77.30\n1025\n15.46\n4\n61.84\n1028\n15.46\n1\n15.46\n1029\n15.46\n9\n139.14\n1042\n15.46\n10\n154.60\n1044\n15.46\n4\n61.84\n1048\n15.46\n15\n231.90\n1050\n15.46\n3\n46.38\n1055\n15.46\n13\n200.98\n1059\n15.46\n11\n170.06\n1060\n15.46\n9\n139.14\n1073\n15.46\n16\n247.36\n1077\n15.46\n5\n77.30\n1085\n15.46\n3\n46.38\n2042\n15.46\n6\n92.76\n2051\n15.46\n10\n154.60\n2054\n15.46\n11\n170.06\n2059\n15.46\n9\n139.14\n3001\n15.46\n15\n231.90\n3009\n15.46\n3\n46.38\n3010\n15.46\n2\n30.92\n3046\n15.46\n14\n216.44\n3063\n15.46\n4\n61.84\n3071\n15.46\n4\n61.84\n3078\n15.46\n5\n77.30\n3100\n15.46\n3\n46.38\n5911\n15.46\n13\n200.98\n6420\n15.46\n6\n92.76\n6431\n15.46\n10\n154.60\n7101\n15.46\n2\n30.92\n7110\n15.46\n4\n61.84\n7337\n15.46\n4\n61.84\n9009\n15.46\n1\n15.46\nTotal\n245\n\u00a33787.70\nFrom: Julia Patel <julia.patel@alphatech.com>\nSent: April 29, 2025 1:19PM\nTo: Sam Thompson <Sam. Thompson@nexgen.co.uk>\nCc: Accounts Payable <accounts@alphatech.com>\nSubject: RE:Invoice NG-INV-2025-00123\nHi Sam,\nThanks for the clarification. We have reviewed and signed the attached invoice. Everything looks in order.\nPleaseproceed with our usual payment process. You can expect payment in the next 5 business days.\nHave a great day!\nBest regards,\nJulia\nFrom: Sam Thompson <Sam. Thompson@nexgen.co.uk>\nSent: April 29, 2025 8:47 AM\nTo: Julia Patel <julia.patel@alphatech.com>\nCc: Accounts Payable <accounts@alphatech.com>\nSubject: RE:Invoice NG-INV-2025-00123\nHi Julia,\nThank you for your query. The 15% VAT is correct for Mailbox 25pk (10323)under standard office supplies. The breakdown on\nInvoice NG-INV-2025-00123 is:\n\u00b7 Subtotal: \u00a33 787.70\n\u00b7 VAT @ 15%: \u00a3568.16\n\u00b7 Total: \u00a34 355.86\nPleaselet me know if you need anything further.\nBest,\nSam\nFrom: Julia Patel <julia.patel@alphatech.com>\nSent: April 28, 2025 9:15PM\nTo: Sam Thompson <Sam. Thompson@nexgen.co.uk>\nCc: Accounts Payable <accounts@alphatech.com>\nSubject: RE:Invoice NG-INV-2025-00123\nHi Sam,\nThanks for sending over the invoice. Could you please confirm the VAT rate applied? Our records show recent contracts at reduced\nVAT, so we just want to ensure the 15%rate is correct for this shipment.\nKind regards,\nJulia Patel\nAlpha Tech Solutions\naccounts@alphatech.com\n+44 (0)1098 765432\nFrom: Sam Thompson <Sam.Thompson@nexgen.co.uk>\nSent: April 24, 2025 11:03AM\nTo: Accounts Payable<accounts@alphatech.com>\nSubject: Invoice NG-INV-2025-00123\nDear Accounts Team,\nPleasefind attached Invoice NG-INV-2025-00123 for 245 units of 10323-Mailbox 25pk, shipped on 24 April 2025.\n\u00b7 Excl. VAT: \u00a33 787.70\n\u00b7 Incl. VAT (15%): \u00a34 355.86\nKindly sign and return the invoice to info@nexgen.co.uk. Queries must be raised within 30 days of issue (by 24 May 2025), and\npayment is due within 45 days of issue (by 8 June 2025).\nBest regards,\nSam Thompson\nNEXGEN Ltd.\ ...
#     "pages": [
#         {
#             "pageNumber": 1,
#             "angle": -0.32409998774528503,
#             "width": 8.2639,
#             "height": 11.6806,
#             "unit": "inch",
#             "words": [
#                 {
#                     "content": "NEXGEN",
#                     "polygon": [
#                         0.44,
#                         0.5567,
#                         1.9404,
#                         0.5702,
#                         1.9404,
#                         0.8888,
#                         0.4376,
#                         0.8777
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 0,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Unit",
#                     "polygon": [
#                         2.9481,
#                         0.5099,
#                         3.1958,
#                         0.5096,
#                         3.1955,
#                         0.6546,
#                         2.9478,
#                         0.6547
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 7,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "4,",
#                     "polygon": [
#                         3.2315,
#                         0.5091,
#                         3.322,
#                         0.5082,
#                         3.3218,
#                         0.6548,
#                         3.2312,
#                         0.6545
#                     ],
#                     "confidence": 0.987,
#                     "span": {
#                         "offset": 12,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Innovation",
#                     "polygon": [
#                         3.3696,
#                         0.5078,
#                         3.9651,
#                         0.5028,
#                         3.9652,
#                         0.6478,
#                         3.3695,
#                         0.654
#                     ],
#                     "confidence": 0.963,
#                     "span": {
#                         "offset": 15,
#                         "length": 10
#                     }
#                 },
#                 {
#                     "content": "Drive",
#                     "polygon": [
#                         4.0079,
#                         0.5022,
#                         4.3146,
#                         0.4995,
#                         4.3146,
#                         0.643,
#                         4.008,
#                         0.6475
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 26,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "Phone:",
#                     "polygon": [
#                         5.4627,
#                         0.4769,
#                         5.8579,
#                         0.4701,
#                         5.8584,
#                         0.6202,
#                         5.4633,
#                         0.6245
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 32,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "+44",
#                     "polygon": [
#                         5.9042,
#                         0.4694,
#                         6.1238,
#                         0.4653,
#                         6.1244,
#                         0.6158,
#                         5.9047,
#                         0.62
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 39,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "(0)1234",
#                     "polygon": [
#                         6.1628,
#                         0.4646,
#                         6.5653,
#                         0.458,
#                         6.5657,
#                         0.6088,
#                         6.1634,
#                         0.6153
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 43,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "567890",
#                     "polygon": [
#                         6.6068,
#                         0.4577,
#                         7.0312,
#                         0.453,
#                         7.0312,
#                         0.5975,
#                         6.6071,
#                         0.6076
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 51,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Milton",
#                     "polygon": [
#                         2.9497,
#                         0.6848,
#                         3.3233,
#                         0.6856,
#                         3.3231,
#                         0.827,
#                         2.9496,
#                         0.8266
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 58,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Keynes",
#                     "polygon": [
#                         3.37,
#                         0.6858,
#                         3.7716,
#                         0.6853,
#                         3.7713,
#                         0.827,
#                         3.3698,
#                         0.827
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 65,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "info@nexgen.co.uk",
#                     "polygon": [
#                         5.4574,
#                         0.6495,
#                         6.5738,
#                         0.6369,
#                         6.5746,
#                         0.7808,
#                         5.4583,
#                         0.7972
#                     ],
#                     "confidence": 0.952,
#                     "span": {
#                         "offset": 72,
#                         "length": 17
#                     }
#                 },
#                 {
#                     "content": "Innovation",
#                     "polygon": [
#                         0.434,
#                         1.0044,
#                         1.0502,
#                         1.0117,
#                         1.049,
#                         1.1564,
#                         0.4329,
#                         1.1459
#                     ],
#                     "confidence": 0.99,
#                     "span": {
#                         "offset": 90,
#                         "length": 10
#                     }
#                 },
#                 {
#                     "content": "Drives",
#                     "polygon": [
#                         1.081,
#                         1.0118,
#                         1.4317,
#                         1.0162,
#                         1.4302,
#                         1.1619,
#                         1.0798,
#                         1.1572
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 101,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Progress",
#                     "polygon": [
#                         1.4649,
#                         1.0166,
#                         1.9518,
#                         1.0234,
#                         1.9518,
#                         1.1663,
#                         1.4633,
#                         1.1621
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 108,
#                         "length": 8
#                     }
#                 },
#                 {
#                     "content": "Buckinghamshire",
#                     "polygon": [
#                         2.9528,
#                         0.8512,
#                         3.9436,
#                         0.8443,
#                         3.9436,
#                         0.9906,
#                         2.953,
#                         0.9981
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 117,
#                         "length": 15
#                     }
#                 },
#                 {
#                     "content": "MK9",
#                     "polygon": [
#                         2.95,
#                         1.0248,
#                         3.216,
#                         1.0245,
#                         3.2161,
#                         1.1578,
#                         2.9503,
#                         1.1578
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 133,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "1FH",
#                     "polygon": [
#                         3.2534,
#                         1.0242,
#                         3.4642,
#                         1.0232,
#                         3.4642,
#                         1.1556,
#                         3.2535,
#                         1.1578
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 137,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "BILL",
#                     "polygon": [
#                         0.4333,
#                         1.4112,
#                         0.7028,
#                         1.4129,
#                         0.7019,
#                         1.5456,
#                         0.4328,
#                         1.5429
#                     ],
#                     "confidence": 0.989,
#                     "span": {
#                         "offset": 141,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "TO",
#                     "polygon": [
#                         0.7311,
#                         1.4132,
#                         0.9188,
#                         1.413,
#                         0.9188,
#                         1.5456,
#                         0.7302,
#                         1.5456
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 146,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "SHIP",
#                     "polygon": [
#                         5.4605,
#                         1.3687,
#                         5.7608,
#                         1.3656,
#                         5.7609,
#                         1.498,
#                         5.4607,
#                         1.5
#                     ],
#                     "confidence": 0.99,
#                     "span": {
#                         "offset": 149,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "TO",
#                     "polygon": [
#                         5.7954,
#                         1.3651,
#                         5.981,
#                         1.3631,
#                         5.981,
#                         1.4944,
#                         5.7954,
#                         1.4975
#                     ],
#                     "confidence": 0.997,
#                     "span": {
#                         "offset": 154,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "AlphaTech",
#                     "polygon": [
#                         0.435,
#                         1.6217,
#                         1.0438,
#                         1.6274,
#                         1.043,
#                         1.7759,
#                         0.4348,
#                         1.7712
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 157,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "Solutions",
#                     "polygon": [
#                         1.0826,
#                         1.6275,
#                         1.6208,
#                         1.6312,
#                         1.6208,
#                         1.7755,
#                         1.0816,
#                         1.7761
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 167,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "AlphaTech",
#                     "polygon": [
#                         5.4553,
#                         1.5775,
#                         6.0614,
#                         1.5671,
#                         6.0624,
#                         1.7129,
#                         5.4562,
#                         1.7224
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 177,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "Solutions",
#                     "polygon": [
#                         6.1018,
#                         1.5665,
#                         6.6431,
#                         1.5619,
#                         6.6431,
#                         1.7027,
#                         6.1027,
#                         1.7127
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 187,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "22",
#                     "polygon": [
#                         0.4383,
#                         1.796,
#                         0.587,
#                         1.7976,
#                         0.5862,
#                         1.9436,
#                         0.4377,
#                         1.9431
#                     ],
#                     "confidence": 0.996,
#                     "span": {
#                         "offset": 197,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Regent",
#                     "polygon": [
#                         0.6278,
#                         1.799,
#                         1.0332,
#                         1.8019,
#                         1.032,
#                         1.9491,
#                         0.6267,
#                         1.944
#                     ],
#                     "confidence": 0.997,
#                     "span": {
#                         "offset": 200,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Street",
#                     "polygon": [
#                         1.0668,
#                         1.8021,
#                         1.4211,
#                         1.8044,
#                         1.4211,
#                         1.9482,
#                         1.0656,
#                         1.9498
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 207,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Warehouse",
#                     "polygon": [
#                         5.4551,
#                         1.7453,
#                         6.1081,
#                         1.7346,
#                         6.1107,
#                         1.8782,
#                         5.4574,
#                         1.886
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 214,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "5,",
#                     "polygon": [
#                         6.1478,
#                         1.7338,
#                         6.2368,
#                         1.732,
#                         6.2397,
#                         1.8753,
#                         6.1506,
#                         1.8773
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 224,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Met",
#                     "polygon": [
#                         6.2836,
#                         1.7312,
#                         6.5035,
#                         1.7264,
#                         6.5063,
#                         1.8713,
#                         6.2866,
#                         1.8743
#                     ],
#                     "confidence": 0.997,
#                     "span": {
#                         "offset": 227,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "Business",
#                     "polygon": [
#                         6.548,
#                         1.7255,
#                         7.0277,
#                         1.716,
#                         7.0308,
#                         1.8601,
#                         6.5508,
#                         1.8702
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 231,
#                         "length": 8
#                     }
#                 },
#                 {
#                     "content": "Park",
#                     "polygon": [
#                         7.0675,
#                         1.7151,
#                         7.3273,
#                         1.71,
#                         7.3279,
#                         1.8519,
#                         7.0706,
#                         1.8592
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 240,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "London",
#                     "polygon": [
#                         0.4399,
#                         1.9705,
#                         0.896,
#                         1.9736,
#                         0.896,
#                         2.1038,
#                         0.4397,
#                         2.1003
#                     ],
#                     "confidence": 0.998,
#                     "span": {
#                         "offset": 245,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Leicester",
#                     "polygon": [
#                         5.4618,
#                         1.9214,
#                         5.9753,
#                         1.9175,
#                         5.9753,
#                         2.0442,
#                         5.4623,
#                         2.0475
#                     ],
#                     "confidence": 0.997,
#                     "span": {
#                         "offset": 252,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "SWIY",
#                     "polygon": [
#                         0.4381,
#                         2.1372,
#                         0.7617,
#                         2.1391,
#                         0.7607,
#                         2.2756,
#                         0.4378,
#                         2.2724
#                     ],
#                     "confidence": 0.544,
#                     "span": {
#                         "offset": 262,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "4PD",
#                     "polygon": [
#                         0.7952,
#                         2.1392,
#                         1.0387,
#                         2.14,
#                         1.0387,
#                         2.2757,
#                         0.7942,
#                         2.2757
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 267,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "LE19",
#                     "polygon": [
#                         5.4601,
#                         2.0869,
#                         5.7073,
#                         2.0855,
#                         5.7083,
#                         2.2165,
#                         5.4608,
#                         2.2186
#                     ],
#                     "confidence": 0.98,
#                     "span": {
#                         "offset": 271,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "1WD",
#                     "polygon": [
#                         5.7417,
#                         2.0846,
#                         6.0153,
#                         2.0809,
#                         6.0153,
#                         2.2118,
#                         5.7426,
#                         2.2162
#                     ],
#                     "confidence": 0.996,
#                     "span": {
#                         "offset": 276,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "Invoice",
#                     "polygon": [
#                         0.7997,
#                         2.7894,
#                         1.2145,
#                         2.7896,
#                         1.2143,
#                         2.9194,
#                         0.7997,
#                         2.9186
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 280,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "No.",
#                     "polygon": [
#                         1.2571,
#                         2.7897,
#                         1.4549,
#                         2.7902,
#                         1.4545,
#                         2.9192,
#                         1.2569,
#                         2.9192
#                     ],
#                     "confidence": 0.997,
#                     "span": {
#                         "offset": 288,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "Invoice",
#                     "polygon": [
#                         2.2627,
#                         2.7771,
#                         2.67,
#                         2.7765,
#                         2.6696,
#                         2.9045,
#                         2.2628,
#                         2.9053
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 292,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "Date",
#                     "polygon": [
#                         2.7122,
#                         2.7765,
#                         2.9848,
#                         2.7765,
#                         2.9848,
#                         2.9056,
#                         2.7118,
#                         2.9048
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 300,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "Ship",
#                     "polygon": [
#                         3.8227,
#                         2.7596,
#                         4.078,
#                         2.7588,
#                         4.0776,
#                         2.8973,
#                         3.8227,
#                         2.8973
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 305,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "Date",
#                     "polygon": [
#                         4.119,
#                         2.7589,
#                         4.3888,
#                         2.758,
#                         4.3888,
#                         2.8956,
#                         4.1185,
#                         2.8971
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 310,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "Purchase",
#                     "polygon": [
#                         5.1491,
#                         2.7325,
#                         5.6672,
#                         2.7266,
#                         5.6675,
#                         2.8588,
#                         5.1501,
#                         2.8671
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 315,
#                         "length": 8
#                     }
#                 },
#                 {
#                     "content": "Order",
#                     "polygon": [
#                         5.7042,
#                         2.7265,
#                         6.0495,
#                         2.7229,
#                         6.0495,
#                         2.8575,
#                         5.7044,
#                         2.8584
#                     ],
#                     "confidence": 0.998,
#                     "span": {
#                         "offset": 324,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "Customer",
#                     "polygon": [
#                         6.6852,
#                         2.6965,
#                         7.2535,
#                         2.6872,
#                         7.2558,
#                         2.8204,
#                         6.688,
#                         2.8289
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 330,
#                         "length": 8
#                     }
#                 },
#                 {
#                     "content": "Ref.",
#                     "polygon": [
#                         7.2908,
#                         2.6864,
#                         7.5102,
#                         2.6801,
#                         7.5106,
#                         2.8172,
#                         7.293,
#                         2.8199
#                     ],
#                     "confidence": 0.989,
#                     "span": {
#                         "offset": 339,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "NG-INV-2025-00123",
#                     "polygon": [
#                         0.5461,
#                         3.0291,
#                         1.7178,
#                         3.0242,
#                         1.7178,
#                         3.1601,
#                         0.5464,
#                         3.164
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 344,
#                         "length": 17
#                     }
#                 },
#                 {
#                     "content": "2025-04-24",
#                     "polygon": [
#                         2.2828,
#                         3.016,
#                         2.962,
#                         3.0157,
#                         2.962,
#                         3.1467,
#                         2.2827,
#                         3.1471
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 362,
#                         "length": 10
#                     }
#                 },
#                 {
#                     "content": "2025-04-19",
#                     "polygon": [
#                         3.7789,
#                         2.9965,
#                         4.4319,
#                         2.9945,
#                         4.4313,
#                         3.1257,
#                         3.7789,
#                         3.1295
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 373,
#                         "length": 10
#                     }
#                 },
#                 {
#                     "content": "PO-556423",
#                     "polygon": [
#                         5.2686,
#                         2.9744,
#                         5.924,
#                         2.9691,
#                         5.924,
#                         3.0973,
#                         5.2694,
#                         3.1049
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 384,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "ALTEC-SLN",
#                     "polygon": [
#                         6.7648,
#                         2.9378,
#                         7.4294,
#                         2.929,
#                         7.4298,
#                         3.0596,
#                         6.7662,
#                         3.0684
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 394,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "Product",
#                     "polygon": [
#                         0.5854,
#                         3.6839,
#                         1.0771,
#                         3.6819,
#                         1.0771,
#                         3.8119,
#                         0.5858,
#                         3.8143
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 404,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "Code",
#                     "polygon": [
#                         1.1092,
#                         3.6816,
#                         1.4268,
#                         3.681,
#                         1.4268,
#                         3.8108,
#                         1.1091,
#                         3.8122
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 412,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "Description",
#                     "polygon": [
#                         1.8901,
#                         3.6685,
#                         2.6024,
#                         3.6653,
#                         2.6024,
#                         3.8035,
#                         1.8901,
#                         3.8042
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 417,
#                         "length": 11
#                     }
#                 },
#                 {
#                     "content": "Units",
#                     "polygon": [
#                         3.3187,
#                         3.652,
#                         3.6468,
#                         3.6523,
#                         3.6468,
#                         3.7727,
#                         3.3185,
#                         3.7732
#                     ],
#                     "confidence": 0.996,
#                     "span": {
#                         "offset": 429,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "Excl.",
#                     "polygon": [
#                         4.5838,
#                         3.6287,
#                         4.8682,
#                         3.6262,
#                         4.8682,
#                         3.7486,
#                         4.5839,
#                         3.7505
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 435,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "VAT",
#                     "polygon": [
#                         5.8331,
#                         3.6067,
#                         6.1123,
#                         3.6043,
#                         6.1123,
#                         3.725,
#                         5.8332,
#                         3.7272
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 441,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "Incl.",
#                     "polygon": [
#                         7.0919,
#                         3.5868,
#                         7.3565,
#                         3.5831,
#                         7.3565,
#                         3.697,
#                         7.0941,
#                         3.699
#                     ],
#                     "confidence": 0.686,
#                     "span": {
#                         "offset": 445,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "10323",
#                     "polygon": [
#                         0.8338,
#                         3.9259,
#                         1.1757,
#                         3.9262,
#                         1.1757,
#                         4.0491,
#                         0.8339,
#                         4.0494
#                     ],
#                     "confidence": 0.998,
#                     "span": {
#                         "offset": 462,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "MAILBOX",
#                     "polygon": [
#                         1.8076,
#                         3.9021,
#                         2.3566,
#                         3.9005,
#                         2.3564,
#                         4.036,
#                         1.8081,
#                         4.0373
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 468,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "25PK",
#                     "polygon": [
#                         2.3922,
#                         3.8999,
#                         2.6878,
#                         3.8985,
#                         2.6878,
#                         4.0347,
#                         2.3919,
#                         4.0362
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 476,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "245",
#                     "polygon": [
#                         3.3715,
#                         3.8934,
#                         3.5955,
#                         3.8924,
#                         3.5955,
#                         4.017,
#                         3.3713,
#                         4.0174
#                     ],
#                     "confidence": 0.995,
#                     "span": {
#                         "offset": 481,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "3787.70",
#                     "polygon": [
#                         4.4959,
#                         3.8679,
#                         4.9595,
#                         3.8652,
#                         4.9595,
#                         3.9956,
#                         4.496,
#                         3.9981
#                     ],
#                     "confidence": 0.996,
#                     "span": {
#                         "offset": 485,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "568.16",
#                     "polygon": [
#                         5.789,
#                         3.8445,
#                         6.158,
#                         3.8414,
#                         6.158,
#                         3.969,
#                         5.7891,
#                         3.9741
#                     ],
#                     "confidence": 0.997,
#                     "span": {
#                         "offset": 493,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "4355.86",
#                     "polygon": [
#                         7.0052,
#                         3.8155,
#                         7.4649,
#                         3.8092,
#                         7.4649,
#                         3.9366,
#                         7.0068,
#                         3.941
#                     ],
#                     "confidence": 0.996,
#                     "span": {
#                         "offset": 500,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "15%",
#                     "polygon": [
#                         5.8024,
#                         4.0613,
#                         6.2379,
#                         4.0612,
#                         6.2379,
#                         4.289,
#                         5.8004,
#                         4.2866
#                     ],
#                     "confidence": 0.988,
#                     "span": {
#                         "offset": 508,
#                         "length": 3
#                     }
#                 },
#                 {
#                     "content": "COMMENTS",
#                     "polygon": [
#                         3.7284,
#                         4.5159,
#                         4.4858,
#                         4.51,
#                         4.4858,
#                         4.6438,
#                         3.7286,
#                         4.648
#                     ],
#                     "confidence": 0.946,
#                     "span": {
#                         "offset": 512,
#                         "length": 8
#                     }
#                 },
#                 {
#                     "content": "Expect",
#                     "polygon": [
#                         0.7522,
#                         4.6759,
#                         1.5126,
#                         4.6719,
#                         1.5022,
#                         5.207,
#                         0.7444,
#                         5.182
#                     ],
#                     "confidence": 0.83,
#                     "span": {
#                         "offset": 521,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "payment",
#                     "polygon": [
#                         1.6212,
#                         4.6696,
#                         2.5262,
#                         4.6771,
#                         2.5098,
#                         5.2412,
#                         1.6113,
#                         5.2094
#                     ],
#                     "confidence": 0.605,
#                     "span": {
#                         "offset": 528,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "by",
#                     "polygon": [
#                         2.6348,
#                         4.6764,
#                         3.0694,
#                         4.6753,
#                         3.0552,
#                         5.2501,
#                         2.6187,
#                         5.2419
#                     ],
#                     "confidence": 0.825,
#                     "span": {
#                         "offset": 536,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "6",
#                     "polygon": [
#                         3.359,
#                         4.6803,
#                         3.4677,
#                         4.6814,
#                         3.456,
#                         5.2585,
#                         3.3461,
#                         5.2568
#                     ],
#                     "confidence": 0.948,
#                     "span": {
#                         "offset": 539,
#                         "length": 1
#                     }
#                 },
#                 {
#                     "content": "May!",
#                     "polygon": [
#                         3.5763,
#                         4.6826,
#                         4.3488,
#                         4.7084,
#                         4.3488,
#                         5.2585,
#                         3.5659,
#                         5.2585
#                     ],
#                     "confidence": 0.865,
#                     "span": {
#                         "offset": 541,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "REMIT",
#                     "polygon": [
#                         0.4665,
#                         6.2191,
#                         0.8716,
#                         6.2176,
#                         0.8719,
#                         6.3518,
#                         0.467,
#                         6.3536
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 546,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "PAYMENT",
#                     "polygon": [
#                         0.9094,
#                         6.2172,
#                         1.5215,
#                         6.2095,
#                         1.5214,
#                         6.3464,
#                         0.9098,
#                         6.3514
#                     ],
#                     "confidence": 0.992,
#                     "span": {
#                         "offset": 552,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "TO",
#                     "polygon": [
#                         1.5505,
#                         6.2095,
#                         1.7397,
#                         6.2083,
#                         1.7396,
# ...
#                             "polygon": [
#                                 0.4673,
#                                 6.4321,
#                                 0.9702,
#                                 6.4302,
#                                 0.9702,
#                                 6.5563,
#                                 0.4675,
#                                 6.5587
#                             ]
#                         }
#                     ],
#                     "confidence": 0.968,
#                     "spans": [
#                         {
#                             "offset": 581,
#                             "length": 6
#                         }
#                     ]
#                 },
#                 "ShippingAddress": {
#                     "type": "address",
#                     "content": "Warehouse 5, Met Business Park\nLeicester\nLE19 1WD",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 1,
#                             "polygon": [
#                                 5.4537,
#                                 1.7378,
#                                 7.3273,
#                                 1.71,
#                                 7.3345,
#                                 2.1926,
#                                 5.4608,
#                                 2.2204
#                             ]
#                         }
#                     ],
#                     "confidence": 0.873,
#                     "spans": [
#                         {
#                             "offset": 214,
#                             "length": 30
#                         },
#                         {
#                             "offset": 252,
#                             "length": 9
#                         },
#                         {
#                             "offset": 271,
#                             "length": 8
#                         }
#                     ],
#                     "valueAddress": {
#                         "postalCode": "LE19 1WD",
#                         "city": "Leicester",
#                         "streetAddress": "",
#                         "house": "Warehouse 5, Met Business Park"
#                     }
#                 },
#                 "ShippingAddressRecipient": {
#                     "type": "string",
#                     "valueString": "AlphaTech Solutions",
#                     "content": "AlphaTech Solutions",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 1,
#                             "polygon": [
#                                 5.4542,
#                                 1.5752,
#                                 6.6431,
#                                 1.5592,
#                                 6.645,
#                                 1.7064,
#                                 5.4562,
#                                 1.7224
#                             ]
#                         }
#                     ],
#                     "confidence": 0.95,
#                     "spans": [
#                         {
#                             "offset": 177,
#                             "length": 19
#                         }
#                     ]
#                 },
#                 "VendorAddress": {
#                     "type": "address",
#                     "content": "Unit 4, Innovation Drive\nMilton Keynes\nBuckinghamshire\nMK9 1FH",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 1,
#                             "polygon": [
#                                 2.9473,
#                                 0.504,
#                                 4.3146,
#                                 0.4995,
#                                 4.3168,
#                                 1.1543,
#                                 2.9495,
#                                 1.1588
#                             ]
#                         }
#                     ],
#                     "confidence": 0.886,
#                     "spans": [
#                         {
#                             "offset": 7,
#                             "length": 24
#                         },
#                         {
#                             "offset": 58,
#                             "length": 13
#                         },
#                         {
#                             "offset": 117,
#                             "length": 23
#                         }
#                     ],
#                     "valueAddress": {
#                         "houseNumber": "Unit 4",
#                         "road": "Innovation Drive",
#                         "postalCode": "MK9 1FH",
#                         "city": "Milton Keynes",
#                         "streetAddress": "Unit 4 Innovation Drive",
#                         "stateDistrict": "Buckinghamshire"
#                     }
#                 },
#                 "VendorAddressRecipient": {
#                     "type": "string",
#                     "valueString": "NEXGEN\nInnovation Drives Progress",
#                     "content": "NEXGEN\nInnovation Drives Progress",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 1,
#                             "polygon": [
#                                 0.4399,
#                                 0.5507,
#                                 1.9595,
#                                 0.5704,
#                                 1.9518,
#                                 1.1687,
#                                 0.4321,
#                                 1.1489
#                             ]
#                         }
#                     ],
#                     "confidence": 0.348,
#                     "spans": [
#                         {
#                             "offset": 0,
#                             "length": 6
#                         },
#                         {
#                             "offset": 90,
#                             "length": 26
#                         }
#                     ]
#                 },
#                 "VendorName": {
#                     "type": "string",
#                     "valueString": "NEXGEN\nInnovation Drives Progress",
#                     "content": "NEXGEN\nInnovation Drives Progress",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 1,
#                             "polygon": [
#                                 0.4399,
#                                 0.5507,
#                                 1.9595,
#                                 0.5704,
#                                 1.9518,
#                                 1.1687,
#                                 0.4321,
#                                 1.1489
#                             ]
#                         }
#                     ],
#                     "confidence": 0.348,
#                     "spans": [
#                         {
#                             "offset": 0,
#                             "length": 6
#                         },
#                         {
#                             "offset": 90,
#                             "length": 26
#                         }
#                     ]
#                 },
#                 "InvoiceTotal": {
#                     "type": "currency",
#                     "valueCurrency": {
#                         "currencySymbol": "\u00a3",
#                         "amount": 4355.86,
#                         "currencyCode": "GBP"
#                     },
#                     "content": "\u00a34 355.86",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 3,
#                             "polygon": [
#                                 1.5246,
#                                 6.0987,
#                                 2.0831,
#                                 6.097,
#                                 2.0835,
#                                 6.2206,
#                                 1.525,
#                                 6.2223
#                             ]
#                         }
#                     ],
#                     "confidence": 0.927,
#                     "spans": [
#                         {
#                             "offset": 2541,
#                             "length": 9
#                         }
#                     ]
#                 },
#                 "SubTotal": {
#                     "type": "currency",
#                     "valueCurrency": {
#                         "currencySymbol": "\u00a3",
#                         "amount": 3787.7,
#                         "currencyCode": "GBP"
#                     },
#                     "content": "\u00a33 787.70",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 3,
#                             "polygon": [
#                                 1.6701,
#                                 5.7366,
#                                 2.1858,
#                                 5.7362,
#                                 2.1859,
#                                 5.8628,
#                                 1.6702,
#                                 5.8632
#                             ]
#                         }
#                     ],
#                     "confidence": 0.938,
#                     "spans": [
#                         {
#                             "offset": 2501,
#                             "length": 9
#                         }
#                     ]
#                 },
#                 "TaxDetails": {
#                     "type": "array",
#                     "valueArray": [
#                         {
#                             "type": "object",
#                             "valueObject": {
#                                 "Amount": {
#                                     "type": "currency",
#                                     "valueCurrency": {
#                                         "currencySymbol": "\u00a3",
#                                         "amount": 568.16,
#                                         "currencyCode": "GBP"
#                                     },
#                                     "content": "\u00a3568.16",
#                                     "boundingRegions": [
#                                         {
#                                             "pageNumber": 3,
#                                             "polygon": [
#                                                 1.8299,
#                                                 5.9133,
#                                                 2.2315,
#                                                 5.91,
#                                                 2.2315,
#                                                 6.0417,
#                                                 1.8305,
#                                                 6.0449
#                                             ]
#                                         }
#                                     ],
#                                     "confidence": 0.913,
#                                     "spans": [
#                                         {
#                                             "offset": 2524,
#                                             "length": 7
#                                         }
#                                     ]
#                                 },
#                                 "Rate": {
#                                     "type": "string",
#                                     "valueString": "15%:",
#                                     "content": "15%:",
#                                     "boundingRegions": [
#                                         {
#                                             "pageNumber": 3,
#                                             "polygon": [
#                                                 1.5707,
#                                                 5.9148,
#                                                 1.8042,
#                                                 5.9134,
#                                                 1.8048,
#                                                 6.0451,
#                                                 1.5714,
#                                                 6.0456
#                                             ]
#                                         }
#                                     ],
#                                     "confidence": 0.907,
#                                     "spans": [
#                                         {
#                                             "offset": 2519,
#                                             "length": 4
#                                         }
#                                     ]
#                                 }
#                             },
#                             "content": "VAT @ 15%: \u00a3568.16",
#                             "boundingRegions": [
#                                 {
#                                     "pageNumber": 3,
#                                     "polygon": [
#                                         1.1787,
#                                         5.9143,
#                                         2.2315,
#                                         5.91,
#                                         2.232,
#                                         6.0434,
#                                         1.1792,
#                                         6.0476
#                                     ]
#                                 }
#                             ],
#                             "confidence": 0.848,
#                             "spans": [
#                                 {
#                                     "offset": 2513,
#                                     "length": 18
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 "TotalTax": {
#                     "type": "currency",
#                     "valueCurrency": {
#                         "currencySymbol": "\u00a3",
#                         "amount": 568.16,
#                         "currencyCode": "GBP"
#                     },
#                     "content": "\u00a3568.16",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 3,
#                             "polygon": [
#                                 1.8299,
#                                 5.9133,
#                                 2.2315,
#                                 5.91,
#                                 2.2315,
#                                 6.0417,
#                                 1.8305,
#                                 6.0449
#                             ]
#                         }
#                     ],
#                     "confidence": 0.843,
#                     "spans": [
#                         {
#                             "offset": 2524,
#                             "length": 7
#                         }
#                     ]
#                 },
#                 "DueDate": {
#                     "type": "date",
#                     "valueDate": "2025-06-08",
#                     "content": "8 June 2025).",
#                     "boundingRegions": [
#                         {
#                             "pageNumber": 4,
#                             "polygon": [
#                                 2.9613,
#                                 2.9674,
#                                 3.6468,
#                                 2.9675,
#                                 3.6468,
#                                 3.121,
#                                 2.9613,
#                                 3.1209
#                             ]
#                         }
#                     ],
#                     "confidence": 0.427,
#                     "spans": [
#                         {
#                             "offset": 3618,
#                             "length": 13
#                         }
#                     ]
#                 }
#             },
#             "confidence": 1,
#             "spans": [
#                 {
#                     "offset": 0,
#                     "length": 4042
#                 }
#             ]
#         }
#     ],
#     "contentFormat": "text"
# }
