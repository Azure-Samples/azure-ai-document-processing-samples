# %% [markdown]
# ## Setup

# %%
import sys
import os
from pathlib import Path
wdir = os.path.abspath('../../../../')
sys.path.append(os.path.join(wdir, 'samples/python/modules/')) # Import local modules

from IPython.display import display, Markdown
import os
import pandas as pd
from dotenv import dotenv_values
import base64
import io
import json
from openai import AzureOpenAI
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeResult, DocumentContentFormat
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from concurrent.futures import ThreadPoolExecutor
from pdf2image import convert_from_bytes

from samples.app_settings import AppSettings
from samples.utils.stopwatch import Stopwatch
from samples.utils.storage_utils import create_json_file
from samples.models.document_processing_result import DataExtractionResult

from samples.models.classification import Classifications
from samples.confidence.confidence_utils import merge_confidence_values
from samples.confidence.openai_confidence import evaluate_confidence as evaluate_openai_confidence
from samples.confidence.document_intelligence_confidence import evaluate_confidence as evaluate_di_confidence
from samples.evaluation.accuracy_evaluator import AccuracyEvaluator
from samples.evaluation.comparison import get_extraction_comparison

# %%
app_settings = AppSettings(dotenv_values(Path(os.path.join(wdir, '.env'))))
scenario_path = Path(os.path.join(wdir, 'samples/python/scenarios/us_tax/'))
scenario_name = "us-tax-1040-extraction"

# Configure the default credential for accessing Azure services using Azure CLI credentials
credential = DefaultAzureCredential(
    exclude_workload_identity_credential=True,
    exclude_developer_cli_credential=True,
    exclude_environment_credential=True,
    exclude_managed_identity_credential=True,
    exclude_powershell_credential=True,
    exclude_shared_token_cache_credential=True,
    exclude_interactive_browser_credential=True
)

openai_token_provider = get_bearer_token_provider(credential, 'https://cognitiveservices.azure.com/.default')

openai_client = AzureOpenAI(
    azure_endpoint=app_settings.openai_endpoint,
    azure_ad_token_provider=openai_token_provider,
    api_version="2024-12-01-preview" # Requires the latest API version for structured outputs.
)

document_intelligence_client = DocumentIntelligenceClient(
    endpoint=app_settings.ai_services_endpoint,
    credential=credential
)

# %%
inputs_path = Path(os.path.join(wdir, 'samples/assets/us_tax/'))
metadata_fname = "us-tax-1040.json" # Change this to the file you want to evaluate
metadata_fpath = Path(os.path.join(inputs_path, metadata_fname))

with open(metadata_fpath, 'r') as f:
    metadata = json.load(f)

pdf_fname = metadata['fname']
pdf_fpath = Path(os.path.join(inputs_path, pdf_fname))

us_tax_1040_evaluator = AccuracyEvaluator(match_keys=[])

# %%
page_images = []

def encode_page(page):
    byte_io = io.BytesIO()
    page.save(byte_io, format='PNG')
    base64_data = base64.b64encode(byte_io.getvalue()).decode('utf-8')
    return {
        "type": "image_url",
        "image_url": {
            "url": f"data:image/png;base64,{base64_data}"
        }
    }

with Stopwatch() as image_stopwatch:
    with open(pdf_fpath, "rb") as f:
        document_bytes = f.read()

    pages = convert_from_bytes(document_bytes)
    
    # Process each page in parallel using multiple processes
    with ThreadPoolExecutor() as executor:
        results = list(executor.map(encode_page, pages))
        page_images.extend(results)

# %% [markdown]
# ## Classify

# %%
classifications = [
    {
        "classification": "US Tax Form 1040",
        "description": "A US individual income tax return form, used to report annual income tax return filed by citizens or residents of the United States.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule 1",
        "description": "A form used to report additional income and adjustments to income.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule 2",
        "description": "A form used to report additional taxes.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule 3",
        "description": "A form used to report nonrefundable credits.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule A",
        "description": "A form used to report itemized deductions for individual income tax returns.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule B",
        "description": "A form used to report interest and ordinary dividends.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule C",
        "description": "A form used to report income or loss from a business operated or a profession practiced as a sole proprietor.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule D",
        "description": "A form used to report capital gains and losses.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule E",
        "description": "A form used to report income or loss from rental real estate, royalties, partnerships, S corporations, estates, trusts, etc.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule EIC",
        "description": "A form used to claim the Earned Income Credit (EIC).",
    },
    {
        "classification": "US Tax Form 1040 - Schedule F",
        "description": "A form used to report profit or loss from farming.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule H",
        "description": "A form used to report household employment taxes.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule J",
        "description": "A form used to figure the tax on a qualified farmer's or fisherman's income.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule R",
        "description": "A form used to claim the Credit for the Elderly or the Disabled.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule SE",
        "description": "A form used to calculate self-employment tax.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule 8812",
        "description": "A form used to claim the Child Tax Credit and Credit for Other Dependents.",
    }
]

# %%
classification_model_map = {
    "US Tax Form 1040": "prebuilt-tax.us.1040",
    "US Tax Form 1040 - Schedule 1": "prebuilt-tax.us.1040Schedule1",
    "US Tax Form 1040 - Schedule 2": "prebuilt-tax.us.1040Schedule2",
    "US Tax Form 1040 - Schedule 3": "prebuilt-tax.us.1040Schedule3",
    "US Tax Form 1040 - Schedule A": "prebuilt-tax.us.1040ScheduleA",
    "US Tax Form 1040 - Schedule B": "prebuilt-tax.us.1040ScheduleB",
    "US Tax Form 1040 - Schedule C": "prebuilt-tax.us.1040ScheduleC",
    "US Tax Form 1040 - Schedule D": "prebuilt-tax.us.1040ScheduleD",
    "US Tax Form 1040 - Schedule E": "prebuilt-tax.us.1040ScheduleE",
    "US Tax Form 1040 - Schedule EIC": "prebuilt-tax.us.1040ScheduleEIC",
    "US Tax Form 1040 - Schedule F": "prebuilt-tax.us.1040ScheduleF",
    "US Tax Form 1040 - Schedule H": "prebuilt-tax.us.1040ScheduleH",
    "US Tax Form 1040 - Schedule J": "prebuilt-tax.us.1040ScheduleJ",
    "US Tax Form 1040 - Schedule R": "prebuilt-tax.us.1040ScheduleR",
    "US Tax Form 1040 - Schedule SE": "prebuilt-tax.us.1040ScheduleSE",
    "US Tax Form 1040 - Schedule 8812": "prebuilt-tax.us.1040Schedule8812"
}

# %%
classify_system_prompt = f"""You are an AI assistant that helps detect the boundaries of sub-section or sub-documents using the provided classifications.

## Classifications

{json.dumps(classifications)}
"""

# %%
classify_user_content = []

# %%
classify_user_prompt = f"""Classify documents that are a US Tax Form in the provided page images.
- A single classification may span multiple page images.
- A single page image may contain multiple classifications.
- If a page image does not contain a classification, ignore it."""

classify_user_content.append({
    "type": "text",
    "text": classify_user_prompt
})

# for each of the page images, add a text content block with the page index, and then another block with the image
for i, page_image in enumerate(page_images):
    classify_user_content.append({
        "type": "text",
        "text": f"Page {i + 1}:"
    })
    classify_user_content.append(page_image)

# %%
with Stopwatch() as classify_stopwatch:
    classify_completion = openai_client.beta.chat.completions.parse(
        model=app_settings.gpt4o_model_deployment_name,
        messages=[
            {
                "role": "system",
                "content": classify_system_prompt,
            },
            {
                "role": "user",
                "content": classify_user_content
            }
        ],
        response_format=Classifications,
        max_tokens=4096,
        temperature=0.1,
        top_p=0.1,
        logprobs=True # Enabled to determine the confidence of the response.
    )

# %%
document_classifications = classify_completion.choices[0].message.parsed

# %%
# DEBUG: Display the document classifications
print(document_classifications.model_dump_json(indent=2))
# Out:
# {
#   "classifications": [
#     {
#       "classification": "US Tax Form 1040",
#       "image_range_start": 1,
#       "image_range_end": 2
#     },
#     {
#       "classification": "US Tax Form 1040 - Schedule 1",
#       "image_range_start": 3,
#       "image_range_end": 4
#     },
#     {
#       "classification": "US Tax Form 1040 - Schedule 2",
#       "image_range_start": 5,
#       "image_range_end": 6
#     }
#   ]
# }

# %%
# For each document classification, group the page images together
classified_images = []
classified_images_pil = []

for classification in document_classifications.classifications:
    image_range_start = classification.image_range_start
    image_range_end = classification.image_range_end

    classified_images.append(page_images[image_range_start - 1:image_range_end])
    classified_images_pil.append(pages[image_range_start - 1:image_range_end])

# %% [markdown]
# ## Extract

# %%
for i, images in enumerate(classified_images):
    classification = document_classifications.classifications[i]
    
    print(f"Classification {i} - {classification.classification}")
    
    images_pil = classified_images_pil[i]
    
    pdf_bytes = io.BytesIO()
    images_pil[0].save(pdf_bytes, format='PDF', resolution=100.0, save_all=True, append_images=images_pil[1:])
    pdf_bytes.seek(0)
    
    # Use the classification of the document to determine the Azure AI Document Intelligence model to use
    model_id = classification_model_map[classification.classification]
        
    with Stopwatch() as di_stopwatch:
        poller = document_intelligence_client.begin_analyze_document(
            model_id=model_id,
            body=pdf_bytes,
            content_type="application/pdf"
        )
        
        result: AnalyzeResult = poller.result()

        doc_result = result.documents[0].fields
            
    # DEBUG: Display the document intelligence content
    display(doc_result)
# Out:
# Classification 0 - US Tax Form 1040
# {'TaxYear': {'type': 'string', 'valueString': '2024', 'content': '2024', 'boundingRegions': [{'pageNumber': 1, 'polygon': [8.2608, 1.0557, 9.7507, 1.0532, 9.7516, 1.5611, 8.2616, 1.5636]}], 'confidence': 0.971, 'spans': [{'offset': 96, 'length': 4}]},
#  'Taxpayer': {'type': 'object', 'valueObject': {'SSN': {'type': 'string', 'valueString': '400-12-3456', 'content': '4 0 0 1 2 3 4 5 6', 'boundingRegions': [{'pageNumber': 1, 'polygon': [13.103, 2.458, 15.9378, 2.4605, 15.9375, 2.7561, 13.1027, 2.7536]}], 'confidence': 0.925, 'spans': [{'offset': 395, 'length': 17}]}, 'LastName': {'type': 'string', 'valueString': 'Sample', 'content': 'Sample', 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.6737, 2.488, 7.4937, 2.491, 7.4928, 2.7458, 6.6728, 2.7427]}], 'confidence': 0.975, 'spans': [{'offset': 388, 'length': 6}]}, 'FirstNameAndInitials': {'type': 'string', 'valueString': 'John Q.', 'content': 'John Q.', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.034, 2.4754, 1.8797, 2.4776, 1.879, 2.7306, 1.0333, 2.7284]}], 'confidence': 0.904, 'spans': [{'offset': 342, 'length': 7}]}, 'Address': {'type': 'address', 'content': '123 Maple Drive\nSpringfield\nIL\n62704', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.0373, 3.8098, 12.4288, 3.8027, 12.4294, 4.7538, 1.0379, 4.7609]}], 'confidence': 0.967, 'spans': [{'offset': 620, 'length': 15}, {'offset': 732, 'length': 11}, {'offset': 750, 'length': 2}, {'offset': 762, 'length': 5}], 'valueAddress': {'houseNumber': '123', 'road': 'Maple Drive', 'postalCode': '62704', 'city': 'Springfield', 'state': 'IL', 'streetAddress': '123 Maple Drive'}}, 'ForeignCountryName': {'type': 'string', 'confidence': 0.975}, 'ForeignProvinceStateOrCounty': {'type': 'string', 'confidence': 0.976}, 'ForeignPostalCode': {'type': 'string', 'confidence': 0.983}}},
#  'Spouse': {'type': 'object', 'valueObject': {'SSN': {'type': 'string', 'valueString': '400-65-4321', 'content': '4 0 0 6 5 4 3 2 1', 'boundingRegions': [{'pageNumber': 1, 'polygon': [13.1051, 3.1337, 15.9376, 3.1347, 15.9375, 3.4178, 13.105, 3.4168]}], 'confidence': 0.879, 'spans': [{'offset': 526, 'length': 17}]}, 'LastName': {'type': 'string', 'valueString': 'Sample', 'content': 'Sample', 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.6739, 3.1538, 7.4938, 3.157, 7.4928, 3.4089, 6.6729, 3.4057]}], 'confidence': 0.946, 'spans': [{'offset': 487, 'length': 6}]}, 'FirstNameAndInitials': {'type': 'string', 'valueString': 'Jane Q.', 'content': 'Jane Q.', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.041, 3.1495, 1.8606, 3.1535, 1.8594, 3.3952, 1.0398, 3.3912]}], 'confidence': 0.894, 'spans': [{'offset': 469, 'length': 7}]}}},
#  'Dependents': {'type': 'array', 'valueArray': [{'type': 'object', 'valueObject': {'Name': {'type': 'string', 'valueString': 'Jack Sample', 'content': 'Jack Sample', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.6278, 10.5116, 4.0189, 10.5187, 4.0176, 10.783, 2.6265, 10.7759]}], 'confidence': 0.977, 'spans': [{'offset': 2576, 'length': 11}]}, 'SSN': {'type': 'string', 'valueString': '400-00-0001', 'content': '4 0 0 000001', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.4513, 10.5182, 9.7396, 10.5134, 9.7401, 10.7591, 7.4518, 10.7639]}], 'confidence': 0.032, 'spans': [{'offset': 2588, 'length': 12}]}, 'RelationshipToFiler': {'type': 'string', 'valueString': 'Son', 'content': 'Son', 'boundingRegions': [{'pageNumber': 1, 'polygon': [9.8731, 10.5348, 10.327, 10.5365, 10.3262, 10.7509, 9.8723, 10.7492]}], 'confidence': 0.988, 'spans': [{'offset': 2601, 'length': 3}]}, 'CreditType': {'type': 'selectionGroup', 'content': ':selected: :unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.5806, 10.5513, 15.0371, 10.5523, 15.037, 10.7967, 12.5805, 10.7957]}], 'confidence': 0.976, 'spans': [{'offset': 2605, 'length': 23}], 'valueSelectionGroup': ['ChildTaxCredit']}}}, {'type': 'object', 'valueObject': {'Name': {'type': 'string', 'valueString': 'Jill Sample', 'content': 'Jill Sample', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.6317, 10.8406, 3.8315, 10.8503, 3.8294, 11.117, 2.6295, 11.1072]}], 'confidence': 0.979, 'spans': [{'offset': 2629, 'length': 11}]}, 'SSN': {'type': 'string', 'valueString': '400-00-0002', 'content': '4 00000002', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.4485, 10.8487, 9.762, 10.852, 9.7617, 11.0969, 7.4482, 11.0937]}], 'confidence': 0.807, 'spans': [{'offset': 2641, 'length': 10}]}, 'RelationshipToFiler': {'type': 'string', 'valueString': 'Daughter', 'content': 'Daughter', 'boundingRegions': [{'pageNumber': 1, 'polygon': [9.8614, 10.8601, 10.8796, 10.8575, 10.8802, 11.1052, 9.862, 11.1078]}], 'confidence': 0.988, 'spans': [{'offset': 2652, 'length': 8}]}, 'CreditType': {'type': 'selectionGroup', 'content': ':selected: :unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.5815, 10.8793, 15.0379, 10.8868, 15.0372, 11.1412, 12.5807, 11.1338]}], 'confidence': 0.976, 'spans': [{'offset': 2661, 'length': 23}], 'valueSelectionGroup': ['ChildTaxCredit']}}}, {'type': 'object', 'valueObject': {'Name': {'type': 'string', 'confidence': 0.995}, 'SSN': {'type': 'string', 'confidence': 0.995}, 'RelationshipToFiler': {'type': 'string', 'confidence': 0.995}, 'CreditType': {'type': 'selectionGroup', 'content': ':unselected: :unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.5784, 11.209, 15.0397, 11.2139, 15.0392, 11.4667, 12.5779, 11.4618]}], 'confidence': 0.981, 'spans': [{'offset': 2695, 'length': 25}]}}}, {'type': 'object', 'valueObject': {'Name': {'type': 'string', 'confidence': 0.995}, 'SSN': {'type': 'string', 'confidence': 0.995}, 'RelationshipToFiler': {'type': 'string', 'confidence': 0.995}, 'CreditType': {'type': 'selectionGroup', 'content': ':unselected: :unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.5813, 11.5539, 15.0394, 11.5505, 15.0397, 11.7939, 12.5816, 11.7973]}], 'confidence': 0.981, 'spans': [{'offset': 2743, 'length': 25}]}}}]},
#  'ThirdPartyDesignee': {'type': 'object', 'valueObject': {'PhoneNumber': {'type': 'string', 'confidence': 0.974}, 'Name': {'type': 'string', 'confidence': 0.975}, 'PersonalIdentificationNumber': {'type': 'string', 'confidence': 0.932}}},
#  'SignatureDetails': {'type': 'object', 'valueObject': {'TaxpayerOccupation': {'type': 'string', 'valueString': 'Engineer', 'content': 'Engineer', 'boundingRegions': [{'pageNumber': 2, 'polygon': [9.0772, 13.2522, 10.0612, 13.2547, 10.0605, 13.5071, 9.0765, 13.5046]}], 'confidence': 0.964, 'spans': [{'offset': 7381, 'length': 8}]}, 'TaxpayerPIN': {'type': 'string', 'valueString': '492132', 'content': '492132', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.0269, 13.3246, 16.0159, 13.3295, 16.015, 13.68, 14.0261, 13.6751]}], 'confidence': 0.979, 'spans': [{'offset': 7498, 'length': 6}]}, 'TaxpayerPhoneNumber': {'type': 'string', 'confidence': 0.938}, 'TaxpayerEmail': {'type': 'string', 'confidence': 0.86}, 'SpouseOccupation': {'type': 'string', 'valueString': 'Engineer', 'content': 'Engineer', 'boundingRegions': [{'pageNumber': 2, 'polygon': [9.076, 14.0867, 10.061, 14.0889, 10.0605, 14.3363, 9.0755, 14.3341]}], 'confidence': 0.906, 'spans': [{'offset': 7415, 'length': 8}]}, 'SpousePIN': {'type': 'string', 'valueString': '482712', 'content': '482712', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.093, 14.1713, 15.9385, 14.1771, 15.9375, 14.5043, 14.092, 14.4985]}], 'confidence': 0.952, 'spans': [{'offset': 7704, 'length': 6}]}}},
#  'PaidPreparer': {'type': 'object', 'valueObject': {'PreparerName': {'type': 'string', 'confidence': 0.932}, 'PreparerPTIN': {'type': 'string', 'confidence': 0.954}, 'IsPreparerSelfEmployed': {'type': 'boolean', 'content': ':unselected:', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.1921, 15.195, 14.4558, 15.1947, 14.456, 15.4458, 14.1923, 15.446]}], 'confidence': 0.979, 'spans': [{'offset': 7815, 'length': 12}], 'valueBoolean': False}, 'PreparerFirmName': {'type': 'string', 'confidence': 0.913}, 'PreparerFirmPhoneNumber': {'type': 'string', 'confidence': 0.94}, 'PreparerFirmAddress': {'type': 'string', 'confidence': 0.86}, 'PreparerFirmEIN': {'type': 'string', 'confidence': 0.939}}},
#  'FilingStatus': {'type': 'selectionGroup', 'content': ':unselected: :unselected:\n:unselected:\n:unselected:\n:selected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.8391, 5.539, 10.5017, 5.5451, 10.5009, 6.4713, 2.8384, 6.4652]}], 'confidence': 0.97, 'spans': [{'offset': 1059, 'length': 25}, {'offset': 1129, 'length': 12}, {'offset': 1183, 'length': 12}, {'offset': 1249, 'length': 10}], 'valueSelectionGroup': ['MarriedFillingSeparately']},
#  'NameOfSpouseOrQualifyingPerson': {'type': 'string', 'valueString': 'Jane Q. Sample', 'content': 'Jane Q. Sample', 'boundingRegions': [{'pageNumber': 1, 'polygon': [8.054, 6.8328, 9.7401, 6.8355, 9.7396, 7.1211, 8.0536, 7.1184]}], 'confidence': 0.871, 'spans': [{'offset': 1469, 'length': 14}]},
#  'PresidentialElectionCampaign': {'type': 'selectionGroup', 'content': ':unselected:\n:unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [13.9916, 5.1593, 15.2606, 5.1636, 15.2597, 5.4299, 13.9907, 5.4256]}], 'confidence': 0.98, 'spans': [{'offset': 1008, 'length': 12}, {'offset': 1025, 'length': 12}]},
#  'DigitalAssets': {'type': 'selectionGroup', 'content': ':unselected:\n:unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [13.9925, 8.3456, 15.2639, 8.3495, 15.2631, 8.6094, 13.9917, 8.6056]}], 'confidence': 0.978, 'spans': [{'offset': 1938, 'length': 12}, {'offset': 1955, 'length': 12}]},
#  'ClaimStatus': {'type': 'selectionGroup', 'content': ':unselected:\n:unselected:\n:unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.6308, 8.7163, 8.1016, 8.7058, 8.1027, 9.2894, 2.6319, 9.3]}], 'confidence': 0.978, 'spans': [{'offset': 1990, 'length': 12}, {'offset': 2022, 'length': 12}, {'offset': 2081, 'length': 12}]},
#  'TaxpayerAgeBlindeness': {'type': 'selectionGroup', 'content': ':selected:\n:unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.2388, 9.5177, 7.5065, 9.5322, 7.5056, 9.801, 3.2379, 9.7865]}], 'confidence': 0.97, 'spans': [{'offset': 2182, 'length': 10}, {'offset': 2226, 'length': 12}], 'valueSelectionGroup': ['Above64']},
#  'SpouseAgeBlindeness': {'type': 'selectionGroup', 'content': ':selected:\n:unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [10.0452, 9.5256, 14.3058, 9.5366, 14.3052, 9.7962, 10.0445, 9.7852]}], 'confidence': 0.971, 'spans': [{'offset': 2257, 'length': 10}, {'offset': 2300, 'length': 12}], 'valueSelectionGroup': ['Above64']},
#  'MoreThanFourDependents': {'type': 'boolean', 'content': ':unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.1966, 11.5171, 2.4543, 11.5162, 2.4552, 11.7712, 2.1975, 11.7721]}], 'confidence': 0.971, 'spans': [{'offset': 2730, 'length': 12}], 'valueBoolean': False},
#  'Box1a': {'type': 'number', 'valueNumber': 154070, 'content': '154,070.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.8451, 11.8528, 15.9707, 11.8524, 15.9708, 12.0968, 14.8452, 12.0972]}], 'confidence': 0.978, 'spans': [{'offset': 2838, 'length': 10}]},
#  'Box1b': {'type': 'string', 'confidence': 0.98},
#  'Box1c': {'type': 'string', 'confidence': 0.983},
#  'Box1d': {'type': 'string', 'confidence': 0.981},
#  'Box1e': {'type': 'string', 'confidence': 0.98},
#  'Box1f': {'type': 'string', 'confidence': 0.98},
#  'Box1g': {'type': 'string', 'confidence': 0.98},
#  'Box1h': {'type': 'string', 'confidence': 0.981},
#  'Box1i': {'type': 'string', 'confidence': 0.979},
#  'Box1z': {'type': 'string', 'confidence': 0.953},
#  'Box2a': {'type': 'string', 'confidence': 0.975},
#  'Box2b': {'type': 'number', 'valueNumber': 350, 'content': '350.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.2629, 15.1972, 15.9711, 15.1984, 15.9707, 15.4242, 15.2625, 15.4229]}], 'confidence': 0.974, 'spans': [{'offset': 3535, 'length': 6}]},
#  'Box3a': {'type': 'number', 'valueNumber': 600, 'content': '600.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [8.2284, 15.5204, 8.9432, 15.5219, 8.9427, 15.7633, 8.2279, 15.7618]}], 'confidence': 0.977, 'spans': [{'offset': 3568, 'length': 6}]},
#  'Box3b': {'type': 'number', 'valueNumber': 820, 'content': '820.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.2602, 15.5253, 15.982, 15.5268, 15.9815, 15.7557, 15.2597, 15.7542]}], 'confidence': 0.972, 'spans': [{'offset': 3599, 'length': 6}]},
#  'Box4a': {'type': 'string', 'confidence': 0.975},
#  'Box4b': {'type': 'string', 'confidence': 0.981},
#  'Box5a': {'type': 'string', 'confidence': 0.98},
#  'Box5b': {'type': 'string', 'confidence': 0.981},
#  'Box6a': {'type': 'string', 'confidence': 0.977},
#  'Box6b': {'type': 'string', 'confidence': 0.981},
#  'Box6cCheckbox': {'type': 'boolean', 'content': ':unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.9142, 16.8771, 13.1691, 16.8767, 13.1696, 17.131, 12.9146, 17.1315]}], 'confidence': 0.971, 'spans': [{'offset': 3895, 'length': 12}], 'valueBoolean': False},
#  'Box7Checkbox': {'type': 'boolean', 'content': ':unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.9159, 17.2161, 13.17, 17.2162, 13.1699, 17.4673, 12.9158, 17.4672]}], 'confidence': 0.971, 'spans': [{'offset': 4018, 'length': 12}], 'valueBoolean': False},
#  'Box7': {'type': 'number', 'valueNumber': 6300, 'content': '6,300.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.0781, 17.194, 15.9707, 17.1913, 15.9714, 17.4293, 15.0788, 17.432]}], 'confidence': 0.973, 'spans': [{'offset': 4033, 'length': 8}]},
#  'Box8': {'type': 'number', 'valueNumber': 5400, 'content': '5,400.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.0786, 17.5274, 15.9707, 17.5266, 15.9709, 17.7643, 15.0788, 17.7651]}], 'confidence': 0.971, 'spans': [{'offset': 4100, 'length': 8}]},
#  'Box9': {'type': 'number', 'valueNumber': 166940, 'content': '166,940.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.8464, 17.864, 15.9707, 17.8637, 15.9708, 18.1007, 14.8465, 18.101]}], 'confidence': 0.977, 'spans': [{'offset': 4230, 'length': 10}]},
#  'Box10': {'type': 'number', 'valueNumber': 10232, 'content': '10,232.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.9619, 18.199, 15.9707, 18.197, 15.9712, 18.4296, 14.9624, 18.4316]}], 'confidence': 0.969, 'spans': [{'offset': 4294, 'length': 9}]},
#  'Box11': {'type': 'number', 'valueNumber': 156708, 'content': '156,708.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.8497, 18.5293, 15.9806, 18.5283, 15.9808, 18.766, 14.8499, 18.767]}], 'confidence': 0.977, 'spans': [{'offset': 4394, 'length': 10}]},
#  'Box12': {'type': 'number', 'valueNumber': 29200, 'content': '29,200.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.9496, 18.8632, 15.9707, 18.8604, 15.9714, 19.1012, 14.9503, 19.1041]}], 'confidence': 0.969, 'spans': [{'offset': 4488, 'length': 9}]},
#  'Box13': {'type': 'string', 'confidence': 0.982},
#  'Box14': {'type': 'number', 'valueNumber': 29200, 'content': '29,200.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.946, 19.533, 15.9707, 19.5321, 15.9709, 19.7629, 14.9462, 19.7638]}], 'confidence': 0.978, 'spans': [{'offset': 4648, 'length': 9}]},
#  'Box15': {'type': 'number', 'valueNumber': 127508, 'content': '127,508.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.8461, 19.8629, 15.9707, 19.86, 15.9713, 20.097, 14.8467, 20.0999]}], 'confidence': 0.977, 'spans': [{'offset': 4752, 'length': 10}]},
#  'Box16FromForm': {'type': 'selectionGroup', 'content': ':unselected:\n:unselected:\n:unselected:', 'boundingRegions': [{'pageNumber': 2, 'polygon': [8.2501, 1.0457, 11.3055, 1.0481, 11.3053, 1.2995, 8.2499, 1.2971]}], 'confidence': 0.976, 'spans': [{'offset': 4984, 'length': 12}, {'offset': 5004, 'length': 12}, {'offset': 5024, 'length': 12}]},
#  'Box16OtherFormNumber': {'type': 'string', 'confidence': 0.982},
#  'Box16': {'type': 'number', 'valueNumber': 18667, 'content': '18,667.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.9624, 1.0249, 15.9818, 1.0204, 15.9828, 1.2494, 14.9634, 1.2538]}], 'confidence': 0.965, 'spans': [{'offset': 5040, 'length': 9}]},
#  'Box17': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5144, 1.3607, 15.9707, 1.3595, 15.9712, 1.5683, 15.5149, 1.5694]}], 'confidence': 0.957, 'spans': [{'offset': 5087, 'length': 4}]},
#  'Box18': {'type': 'number', 'valueNumber': 18667, 'content': '18,667.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.9704, 1.6884, 15.9798, 1.6866, 15.9802, 1.9155, 14.9708, 1.9173]}], 'confidence': 0.971, 'spans': [{'offset': 5118, 'length': 9}]},
#  'Box19': {'type': 'number', 'valueNumber': 4000, 'content': '4,000.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.0811, 2.0257, 15.9818, 2.0239, 15.9822, 2.2476, 15.0815, 2.2494]}], 'confidence': 0.916, 'spans': [{'offset': 5201, 'length': 8}]},
#  'Box20': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5108, 2.3631, 15.9818, 2.362, 15.9823, 2.5731, 15.5113, 2.5742]}], 'confidence': 0.958, 'spans': [{'offset': 5247, 'length': 4}]},
#  'Box21': {'type': 'number', 'valueNumber': 4000, 'content': '4,000.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.0787, 2.6908, 15.9818, 2.6885, 15.9824, 2.9211, 15.0793, 2.9233]}], 'confidence': 0.972, 'spans': [{'offset': 5278, 'length': 8}]},
#  'Box22': {'type': 'number', 'valueNumber': 14667, 'content': '14,667.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.962, 3.0239, 15.9818, 3.024, 15.9818, 3.25, 14.962, 3.2499]}], 'confidence': 0.968, 'spans': [{'offset': 5351, 'length': 9}]},
#  'Box23': {'type': 'number', 'valueNumber': 763, 'content': '763.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.2668, 3.3602, 15.9707, 3.3589, 15.9711, 3.5762, 15.2672, 3.5775]}], 'confidence': 0.966, 'spans': [{'offset': 5436, 'length': 6}]},
#  'Box24': {'type': 'number', 'valueNumber': 15430, 'content': '15,430.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.9661, 3.6935, 15.9818, 3.6915, 15.9822, 3.9172, 14.9665, 3.9192]}], 'confidence': 0.972, 'spans': [{'offset': 5493, 'length': 9}]},
#  'Box25a': {'type': 'number', 'valueNumber': 19000, 'content': '19,000.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.341, 4.3494, 13.3477, 4.3482, 13.348, 4.5929, 12.3413, 4.5941]}], 'confidence': 0.955, 'spans': [{'offset': 5567, 'length': 9}]},
#  'Box25b': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.886, 4.6984, 13.3477, 4.6974, 13.3481, 4.9116, 12.8864, 4.9125]}], 'confidence': 0.957, 'spans': [{'offset': 5596, 'length': 4}]},
#  'Box25c': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8884, 5.0338, 13.3442, 5.0324, 13.3448, 5.2424, 12.889, 5.2438]}], 'confidence': 0.956, 'spans': [{'offset': 5638, 'length': 4}]},
#  'Box25d': {'type': 'number', 'valueNumber': 19000, 'content': '19,000.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.9686, 5.3532, 15.9707, 5.3516, 15.9711, 5.5913, 14.969, 5.5929]}], 'confidence': 0.969, 'spans': [{'offset': 5675, 'length': 9}]},
#  'Box26': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5113, 5.7026, 15.9805, 5.7025, 15.9805, 5.9073, 15.5113, 5.9074]}], 'confidence': 0.958, 'spans': [{'offset': 5804, 'length': 4}]},
#  'Box27': {'type': 'string', 'confidence': 0.974},
#  'Box28': {'type': 'string', 'confidence': 0.975},
#  'Box29': {'type': 'string', 'confidence': 0.976},
#  'Box31': {'type': 'string', 'confidence': 0.975},
#  'Box32': {'type': 'string', 'confidence': 0.953},
#  'Box33': {'type': 'number', 'valueNumber': 19000, 'content': '19,000.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.962, 8.0241, 15.9818, 8.0236, 15.9819, 8.2634, 14.9621, 8.2639]}], 'confidence': 0.97, 'spans': [{'offset': 6179, 'length': 9}]},
#  'Box34': {'type': 'number', 'valueNumber': 3570, 'content': '3,570.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.0769, 8.3587, 15.9818, 8.353, 15.9833, 8.5916, 15.0784, 8.5973]}], 'confidence': 0.965, 'spans': [{'offset': 6298, 'length': 8}]},
#  'Box35Checkbox': {'type': 'boolean', 'content': ':unselected:', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.9152, 8.731, 13.1646, 8.7303, 13.1653, 8.9807, 12.9159, 8.9814]}], 'confidence': 0.976, 'spans': [{'offset': 6392, 'length': 12}], 'valueBoolean': False},
#  'Box35a': {'type': 'number', 'valueNumber': 3570, 'content': '3,570.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.079, 8.6912, 15.9766, 8.6871, 15.9777, 8.9268, 15.0801, 8.9309]}], 'confidence': 0.964, 'spans': [{'offset': 6409, 'length': 8}]},
#  'Box35b': {'type': 'string', 'confidence': 0.934},
#  'Box35c': {'type': 'selectionGroup', 'content': ':unselected:\n:unselected:', 'boundingRegions': [{'pageNumber': 2, 'polygon': [10.4747, 9.0615, 12.3376, 9.0773, 12.3354, 9.3391, 10.4725, 9.3233]}], 'confidence': 0.976, 'spans': [{'offset': 6477, 'length': 12}, {'offset': 6499, 'length': 12}]},
#  'Box35d': {'type': 'string', 'confidence': 0.953},
#  'Box36': {'type': 'string', 'confidence': 0.974},
#  'Box37': {'type': 'string', 'confidence': 0.983},
#  'Box38': {'type': 'string', 'confidence': 0.984},
#  'HasAssignedThirdPartyDesignee': {'type': 'selectionGroup', 'content': ':unselected:\n:selected:', 'boundingRegions': [{'pageNumber': 2, 'polygon': [11.3949, 11.3274, 14.4582, 11.3411, 14.4571, 11.6024, 11.3937, 11.5886]}], 'confidence': 0.96, 'spans': [{'offset': 6917, 'length': 12}, {'offset': 6951, 'length': 10}], 'valueSelectionGroup': ['No']}}
# Classification 1 - US Tax Form 1040 - Schedule 1
# {'TaxYear': {'type': 'string', 'valueString': '2024', 'content': '2024', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.0631, 1.3724, 15.5614, 1.3729, 15.5612, 1.8601, 14.0629, 1.8596]}], 'confidence': 0.967, 'spans': [{'offset': 127, 'length': 4}]},
#  'Taxpayer': {'type': 'object', 'valueObject': {'SSN': {'type': 'string', 'valueString': '400-12-3456', 'content': '400-123-456', 'boundingRegions': [{'pageNumber': 1, 'polygon': [13.5823, 2.6512, 14.8755, 2.6541, 14.875, 2.8898, 13.5818, 2.8869]}], 'confidence': 0.953, 'spans': [{'offset': 374, 'length': 11}]}, 'Name': {'type': 'string', 'valueString': 'John Q. Sample', 'content': 'John Q. Sample', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.0255, 2.6385, 2.7572, 2.6468, 2.7559, 2.9207, 1.0242, 2.9124]}], 'confidence': 0.884, 'spans': [{'offset': 331, 'length': 14}]}}},
#  'Box1': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5104, 4.8573, 15.9762, 4.8561, 15.9767, 5.0783, 15.5109, 5.0794]}], 'confidence': 0.953, 'spans': [{'offset': 782, 'length': 4}]},
#  'Box2a': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5103, 5.1883, 15.9818, 5.1878, 15.982, 5.4087, 15.5105, 5.4092]}], 'confidence': 0.952, 'spans': [{'offset': 810, 'length': 4}]},
#  'Box2b': {'type': 'string', 'confidence': 0.969},
#  'Box3': {'type': 'number', 'valueNumber': 5400, 'content': '5,400.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.08, 5.8493, 15.9707, 5.8501, 15.9705, 6.0904, 15.0798, 6.0896]}], 'confidence': 0.947, 'spans': [{'offset': 935, 'length': 8}]},
#  'Box4': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5105, 6.193, 15.9711, 6.1939, 15.9707, 6.4148, 15.5101, 6.4139]}], 'confidence': 0.945, 'spans': [{'offset': 990, 'length': 4}]},
#  'Box5': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.513, 6.5281, 15.9707, 6.5286, 15.9705, 6.7465, 15.5128, 6.746]}], 'confidence': 0.951, 'spans': [{'offset': 1091, 'length': 4}]},
#  'Box6': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5132, 6.859, 15.9707, 6.8582, 15.9711, 7.0776, 15.5136, 7.0784]}], 'confidence': 0.954, 'spans': [{'offset': 1141, 'length': 4}]},
#  'Box7': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5126, 7.1936, 15.971, 7.1943, 15.9707, 7.4133, 15.5123, 7.4126]}], 'confidence': 0.952, 'spans': [{'offset': 1176, 'length': 4}]},
#  'Box8a': {'type': 'number', 'valueNumber': 0, 'content': '( 0.00 )', 'boundingRegions': [{'pageNumber': 1, 'polygon': [11.4311, 7.8187, 13.3833, 7.861, 13.3764, 8.1778, 11.4243, 8.1356]}], 'confidence': 0.734, 'spans': [{'offset': 1221, 'length': 8}]},
#  'Box8b': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8842, 8.1985, 13.3484, 8.1998, 13.3477, 8.4236, 12.8835, 8.4222]}], 'confidence': 0.951, 'spans': [{'offset': 1244, 'length': 4}]},
#  'Box8c': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.882, 8.529, 13.3483, 8.5302, 13.3477, 8.7555, 12.8814, 8.7543]}], 'confidence': 0.949, 'spans': [{'offset': 1275, 'length': 4}]},
#  'Box8d': {'type': 'number', 'valueNumber': 0, 'content': '( 0.00 )', 'boundingRegions': [{'pageNumber': 1, 'polygon': [11.4437, 8.83, 13.3747, 8.8679, 13.3687, 9.1732, 11.4377, 9.1353]}], 'confidence': 0.802, 'spans': [{'offset': 1332, 'length': 8}]},
#  'Box8e': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8832, 9.1979, 13.3482, 9.1989, 13.3477, 9.4222, 12.8827, 9.4212]}], 'confidence': 0.951, 'spans': [{'offset': 1368, 'length': 4}]},
#  'Box8f': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8824, 9.5298, 13.3483, 9.5311, 13.3477, 9.7555, 12.8818, 9.7542]}], 'confidence': 0.949, 'spans': [{'offset': 1400, 'length': 4}]},
#  'Box8g': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.885, 9.8629, 13.3489, 9.8654, 13.3477, 10.0903, 12.8838, 10.0878]}], 'confidence': 0.95, 'spans': [{'offset': 1442, 'length': 4}]},
#  'Box8h': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8846, 10.1952, 13.3485, 10.1968, 13.3477, 10.4252, 12.8838, 10.4236]}], 'confidence': 0.951, 'spans': [{'offset': 1466, 'length': 4}]},
#  'Box8i': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8861, 10.5302, 13.3488, 10.5323, 13.3477, 10.758, 12.8851, 10.7558]}], 'confidence': 0.95, 'spans': [{'offset': 1494, 'length': 4}]},
#  'Box8j': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8848, 10.8651, 13.3482, 10.8661, 13.3477, 11.0903, 12.8843, 11.0892]}], 'confidence': 0.957, 'spans': [{'offset': 1546, 'length': 4}]},
#  'Box8k': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.883, 11.1981, 13.3484, 11.1996, 13.3477, 11.4235, 12.8823, 11.4219]}], 'confidence': 0.951, 'spans': [{'offset': 1570, 'length': 4}]},
#  'Box8l': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8795, 11.8597, 13.3477, 11.8596, 13.3478, 12.0891, 12.8796, 12.0892]}], 'confidence': 0.946, 'spans': [{'offset': 1718, 'length': 4}]},
#  'Box8m': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8842, 12.197, 13.3482, 12.198, 13.3477, 12.4257, 12.8837, 12.4247]}], 'confidence': 0.944, 'spans': [{'offset': 1798, 'length': 4}]},
#  'Box8n': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8866, 12.532, 13.3477, 12.5331, 13.3472, 12.7609, 12.8861, 12.7598]}], 'confidence': 0.952, 'spans': [{'offset': 1852, 'length': 4}]},
#  'Box8o': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8826, 12.8682, 13.3478, 12.8685, 13.3477, 13.0914, 12.8825, 13.0911]}], 'confidence': 0.953, 'spans': [{'offset': 1907, 'length': 4}]},
#  'Box8p': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8804, 13.1989, 13.3486, 13.2007, 13.3477, 13.4259, 12.8795, 13.424]}], 'confidence': 0.948, 'spans': [{'offset': 1964, 'length': 4}]},
#  'Box8q': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8815, 13.5316, 13.3485, 13.5333, 13.3477, 13.7595, 12.8807, 13.7578]}], 'confidence': 0.953, 'spans': [{'offset': 2036, 'length': 4}]},
#  'Box8r': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8822, 13.8657, 13.3483, 13.8668, 13.3477, 14.0935, 12.8816, 14.0923]}], 'confidence': 0.944, 'spans': [{'offset': 2105, 'length': 4}]},
#  'Box8s': {'type': 'number', 'valueNumber': 0, 'content': '( 0.00 )', 'boundingRegions': [{'pageNumber': 1, 'polygon': [11.4367, 14.4948, 13.3858, 14.5324, 13.3797, 14.8482, 11.4306, 14.8106]}], 'confidence': 0.823, 'spans': [{'offset': 2198, 'length': 8}]},
#  'Box8t': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8773, 15.1966, 13.3578, 15.1961, 13.358, 15.4265, 12.8775, 15.427]}], 'confidence': 0.945, 'spans': [{'offset': 2315, 'length': 4}]},
#  'Box8u': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8817, 15.5354, 13.3554, 15.5351, 13.3555, 15.7612, 12.8818, 15.7615]}], 'confidence': 0.918, 'spans': [{'offset': 2357, 'length': 4}]},
#  'Box8z': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8789, 16.8664, 13.3477, 16.8654, 13.3482, 17.0886, 12.8794, 17.0897]}], 'confidence': 0.952, 'spans': [{'offset': 2497, 'length': 4}]},
#  'Box9': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5066, 17.1996, 15.9707, 17.1968, 15.9721, 17.4207, 15.508, 17.4236]}], 'confidence': 0.965, 'spans': [{'offset': 2550, 'length': 4}]},
#  'Box10': {'type': 'number', 'valueNumber': 5400, 'content': '5,400.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.076, 17.8672, 15.9707, 17.8621, 15.9721, 18.1032, 15.0774, 18.1083]}], 'confidence': 0.965, 'spans': [{'offset': 2683, 'length': 8}]},
#  'Box11': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5136, 1.6917, 15.9818, 1.6906, 15.9823, 1.9103, 15.5141, 1.9114]}], 'confidence': 0.951, 'spans': [{'offset': 2895, 'length': 4}]},
#  'Box12': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5141, 2.355, 15.9707, 2.3548, 15.9708, 2.5765, 15.5142, 2.5767]}], 'confidence': 0.951, 'spans': [{'offset': 3020, 'length': 4}]},
#  'Box13': {'type': 'number', 'valueNumber': 3850, 'content': '3,850.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.084, 2.6878, 15.9818, 2.6856, 15.9824, 2.9281, 15.0846, 2.9303]}], 'confidence': 0.952, 'spans': [{'offset': 3082, 'length': 8}]},
#  'Box14': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5146, 3.0243, 15.9707, 3.0232, 15.9712, 3.2441, 15.5151, 3.2452]}], 'confidence': 0.95, 'spans': [{'offset': 3163, 'length': 4}]},
#  'Box15': {'type': 'number', 'valueNumber': 382, 'content': '382.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.2695, 3.3556, 15.9707, 3.3557, 15.9707, 3.5818, 15.2695, 3.5817]}], 'confidence': 0.961, 'spans': [{'offset': 3233, 'length': 6}]},
#  'Box16': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.512, 3.6951, 15.9707, 3.6948, 15.9708, 3.9084, 15.5121, 3.9087]}], 'confidence': 0.957, 'spans': [{'offset': 3295, 'length': 4}]},
#  'Box17': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5114, 4.0277, 15.9818, 4.0272, 15.982, 4.2475, 15.5116, 4.248]}], 'confidence': 0.952, 'spans': [{'offset': 3347, 'length': 4}]},
#  'Box18': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5134, 4.3609, 15.9802, 4.3614, 15.98, 4.5839, 15.5132, 4.5834]}], 'confidence': 0.921, 'spans': [{'offset': 3397, 'length': 4}]},
#  'Box19a': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5134, 4.6918, 15.9707, 4.6908, 15.9712, 4.9125, 15.5139, 4.9135]}], 'confidence': 0.946, 'spans': [{'offset': 3423, 'length': 4}]},
#  'Box19b': {'type': 'string', 'confidence': 0.962},
#  'Box19c': {'type': 'string', 'confidence': 0.965},
#  'Box20': {'type': 'number', 'valueNumber': 6000, 'content': '6,000.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.0799, 5.6894, 15.9707, 5.6869, 15.9714, 5.926, 15.0806, 5.9285]}], 'confidence': 0.955, 'spans': [{'offset': 3537, 'length': 8}]},
#  'Box21': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.511, 6.03, 15.9707, 6.0291, 15.9711, 6.2477, 15.5114, 6.2486]}], 'confidence': 0.95, 'spans': [{'offset': 3584, 'length': 4}]},
#  'Box23': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5144, 6.6976, 15.9713, 6.6988, 15.9707, 6.9129, 15.5138, 6.9117]}], 'confidence': 0.943, 'spans': [{'offset': 3646, 'length': 4}]},
#  'Box24a': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8851, 7.3629, 13.348, 7.3635, 13.3477, 7.5883, 12.8848, 7.5876]}], 'confidence': 0.949, 'spans': [{'offset': 3712, 'length': 4}]},
#  'Box24b': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8842, 8.0255, 13.3484, 8.0268, 13.3477, 8.2534, 12.8835, 8.252]}], 'confidence': 0.945, 'spans': [{'offset': 3840, 'length': 4}]},
#  'Box24d': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.889, 9.0321, 13.348, 9.0328, 13.3477, 9.2552, 12.8887, 9.2545]}], 'confidence': 0.9, 'spans': [{'offset': 4007, 'length': 4}]},
#  'Box24e': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8828, 9.6958, 13.3587, 9.696, 13.3586, 9.9248, 12.8827, 9.9245]}], 'confidence': 0.922, 'spans': [{'offset': 4094, 'length': 4}]},
#  'Box24f': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8833, 10.0318, 13.3587, 10.0326, 13.3583, 10.2599, 12.8829, 10.2591]}], 'confidence': 0.951, 'spans': [{'offset': 4158, 'length': 4}]},
#  'Box24g': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8864, 10.3664, 13.3482, 10.3674, 13.3477, 10.592, 12.8859, 10.591]}], 'confidence': 0.953, 'spans': [{'offset': 4228, 'length': 4}]},
#  'Box24h': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8806, 11.0296, 13.3477, 11.0291, 13.3479, 11.2595, 12.8808, 11.26]}], 'confidence': 0.952, 'spans': [{'offset': 4349, 'length': 4}]},
#  'Box24i': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8823, 11.6946, 13.3478, 11.6948, 13.3477, 11.9247, 12.8822, 11.9245]}], 'confidence': 0.946, 'spans': [{'offset': 4515, 'length': 4}]},
#  'Box24j': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8855, 12.0358, 13.3587, 12.0342, 13.3595, 12.261, 12.8863, 12.2626]}], 'confidence': 0.95, 'spans': [{'offset': 4559, 'length': 4}]},
#  'Box24k': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8825, 12.3662, 13.3478, 12.3665, 13.3477, 12.5935, 12.8824, 12.5932]}], 'confidence': 0.943, 'spans': [{'offset': 4644, 'length': 4}]},
#  'Box24z': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8815, 13.032, 13.3477, 13.03, 13.3487, 13.2595, 12.8825, 13.2616]}], 'confidence': 0.951, 'spans': [{'offset': 4696, 'length': 4}]},
#  'Box25': {'type': 'number', 'valueNumber': 10232, 'content': '10,232.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [14.9649, 14.027, 15.9821, 14.0282, 15.9818, 14.2681, 14.9646, 14.2669]}], 'confidence': 0.961, 'spans': [{'offset': 4897, 'length': 9}]},
#  'Box26': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5081, 13.3648, 15.9707, 13.3624, 15.9719, 13.5886, 15.5093, 13.591]}], 'confidence': 0.965, 'spans': [{'offset': 4758, 'length': 4}]}}
# Classification 2 - US Tax Form 1040 - Schedule 2
# {'TaxYear': {'type': 'string', 'valueString': '2024', 'content': '2024', 'boundingRegions': [{'pageNumber': 1, 'polygon': [14.0595, 1.3629, 15.5615, 1.3639, 15.5612, 1.8601, 14.0592, 1.8591]}], 'confidence': 0.974, 'spans': [{'offset': 224, 'length': 4}]},
#  'Taxpayer': {'type': 'object', 'valueObject': {'SSN': {'type': 'string', 'valueString': '400-12-3456', 'content': '400-123-456', 'boundingRegions': [{'pageNumber': 1, 'polygon': [13.5756, 2.6427, 14.8754, 2.6449, 14.875, 2.8898, 13.5752, 2.8876]}], 'confidence': 0.963, 'spans': [{'offset': 347, 'length': 11}]}, 'Name': {'type': 'string', 'valueString': 'John Q. Sample', 'content': 'John Q. Sample', 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.0192, 2.6288, 2.7564, 2.6367, 2.7551, 2.922, 1.0179, 2.914]}], 'confidence': 0.918, 'spans': [{'offset': 304, 'length': 14}]}}},
#  'Box1': {'type': 'string', 'confidence': 0.713},
#  'Box2': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5024, 11.3519, 15.9707, 11.3508, 15.9713, 11.5854, 15.503, 11.5865]}], 'confidence': 0.92, 'spans': [{'offset': 1494, 'length': 4}]},
#  'Box3': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5064, 11.8474, 15.9713, 11.8486, 15.9707, 12.0898, 15.5058, 12.0885]}], 'confidence': 0.966, 'spans': [{'offset': 1581, 'length': 4}]},
#  'Box4': {'type': 'number', 'valueNumber': 763, 'content': '763.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.2587, 12.685, 15.9707, 12.6829, 15.9714, 12.9244, 15.2594, 12.9265]}], 'confidence': 0.946, 'spans': [{'offset': 1650, 'length': 6}]},
#  'Box5': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.8765, 13.1911, 13.3477, 13.1907, 13.3479, 13.4192, 12.8767, 13.4196]}], 'confidence': 0.942, 'spans': [{'offset': 1737, 'length': 4}]},
#  'Box6': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.879, 13.6885, 13.3477, 13.6883, 13.3478, 13.9212, 12.8791, 13.9214]}], 'confidence': 0.94, 'spans': [{'offset': 1818, 'length': 4}]},
#  'Box7': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5071, 14.1851, 15.9704, 14.1844, 15.9708, 14.4189, 15.5075, 14.4196]}], 'confidence': 0.946, 'spans': [{'offset': 1896, 'length': 4}]},
#  'Box8Checkbox': {'type': 'boolean', 'content': ':unselected:', 'boundingRegions': [{'pageNumber': 1, 'polygon': [12.9631, 15.0536, 13.2179, 15.053, 13.2185, 15.3071, 12.9636, 15.3076]}], 'confidence': 0.976, 'spans': [{'offset': 2015, 'length': 12}], 'valueBoolean': False},
#  'Box8': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5034, 15.0234, 15.9707, 15.0217, 15.9716, 15.253, 15.5043, 15.2548]}], 'confidence': 0.943, 'spans': [{'offset': 2030, 'length': 4}]},
#  'Box9': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5054, 15.5174, 15.971, 15.5179, 15.9707, 15.7559, 15.5051, 15.7554]}], 'confidence': 0.943, 'spans': [{'offset': 2085, 'length': 4}]},
#  'Box10': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5089, 16.0208, 15.9708, 16.0209, 15.9707, 16.2512, 15.5088, 16.2511]}], 'confidence': 0.942, 'spans': [{'offset': 2167, 'length': 4}]},
#  'Box11': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5069, 16.5266, 15.9707, 16.5259, 15.971, 16.7516, 15.5072, 16.7523]}], 'confidence': 0.942, 'spans': [{'offset': 2220, 'length': 4}]},
#  'Box12': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5068, 17.0269, 15.9707, 17.0258, 15.9712, 17.2522, 15.5073, 17.2533]}], 'confidence': 0.944, 'spans': [{'offset': 2275, 'length': 4}]},
#  'Box13': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5087, 17.8612, 15.9708, 17.8614, 15.9707, 18.0836, 15.5086, 18.0834]}], 'confidence': 0.942, 'spans': [{'offset': 2398, 'length': 4}]},
#  'Box14': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5081, 18.3619, 15.9709, 18.3624, 15.9707, 18.5856, 15.5079, 18.5851]}], 'confidence': 0.946, 'spans': [{'offset': 2508, 'length': 4}]},
#  'Box15': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5055, 18.8626, 15.9707, 18.862, 15.971, 19.0858, 15.5058, 19.0865]}], 'confidence': 0.942, 'spans': [{'offset': 2620, 'length': 4}]},
#  'Box16': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 1, 'polygon': [15.5074, 19.3623, 15.9711, 19.3632, 15.9707, 19.5872, 15.507, 19.5863]}], 'confidence': 0.946, 'spans': [{'offset': 2688, 'length': 4}]},
#  'Box17aExtraInfo': {'type': 'string', 'confidence': 0.963},
#  'Box17a': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8822, 2.6852, 13.3477, 2.6843, 13.3481, 2.9115, 12.8826, 2.9124]}], 'confidence': 0.949, 'spans': [{'offset': 2993, 'length': 4}]},
#  'Box17b': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8815, 3.1846, 13.3452, 3.1845, 13.3452, 3.4102, 12.8815, 3.4103]}], 'confidence': 0.942, 'spans': [{'offset': 3082, 'length': 4}]},
#  'Box17c': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8813, 3.6845, 13.3465, 3.6854, 13.3461, 3.9157, 12.8809, 3.9149]}], 'confidence': 0.944, 'spans': [{'offset': 3147, 'length': 4}]},
#  'Box17d': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.882, 4.5168, 13.3477, 4.5168, 13.3477, 4.7485, 12.882, 4.7485]}], 'confidence': 0.946, 'spans': [{'offset': 3250, 'length': 4}]},
#  'Box17e': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8853, 5.0204, 13.3483, 5.0217, 13.3477, 5.2515, 12.8847, 5.2502]}], 'confidence': 0.93, 'spans': [{'offset': 3322, 'length': 4}]},
#  'Box17f': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8824, 5.5187, 13.3484, 5.5201, 13.3477, 5.7529, 12.8817, 5.7515]}], 'confidence': 0.952, 'spans': [{'offset': 3406, 'length': 4}]},
#  'Box17g': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8811, 6.352, 13.3481, 6.3529, 13.3477, 6.5849, 12.8807, 6.584]}], 'confidence': 0.951, 'spans': [{'offset': 3529, 'length': 4}]},
#  'Box17h': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8802, 7.1875, 13.3469, 7.1885, 13.3464, 7.4187, 12.8797, 7.4177]}], 'confidence': 0.944, 'spans': [{'offset': 3659, 'length': 4}]},
#  'Box17i': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8826, 8.0205, 13.348, 8.0223, 13.3471, 8.2536, 12.8817, 8.2518]}], 'confidence': 0.941, 'spans': [{'offset': 3769, 'length': 4}]},
#  'Box17j': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8804, 8.5214, 13.3455, 8.5232, 13.3446, 8.7538, 12.8795, 8.752]}], 'confidence': 0.951, 'spans': [{'offset': 3817, 'length': 4}]},
#  'Box17k': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8839, 9.0237, 13.3459, 9.0249, 13.3453, 9.2531, 12.8833, 9.252]}], 'confidence': 0.943, 'spans': [{'offset': 3854, 'length': 4}]},
#  'Box17l': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8819, 9.5234, 13.3487, 9.5254, 13.3477, 9.7549, 12.8809, 9.7529]}], 'confidence': 0.946, 'spans': [{'offset': 3908, 'length': 4}]},
#  'Box17m': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8817, 10.0252, 13.3466, 10.0256, 13.3464, 10.2549, 12.8815, 10.2545]}], 'confidence': 0.932, 'spans': [{'offset': 3994, 'length': 4}]},
#  'Box17n': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8812, 10.5263, 13.3477, 10.5262, 13.3477, 10.7541, 12.8812, 10.7542]}], 'confidence': 0.942, 'spans': [{'offset': 4080, 'length': 4}]},
#  'Box17o': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8782, 11.3564, 13.3477, 11.3574, 13.3472, 11.5906, 12.8777, 11.5895]}], 'confidence': 0.95, 'spans': [{'offset': 4203, 'length': 4}]},
#  'Box17p': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8811, 12.1888, 13.3478, 12.1889, 13.3477, 12.4228, 12.881, 12.4227]}], 'confidence': 0.949, 'spans': [{'offset': 4335, 'length': 4}]},
#  'Box17q': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8818, 12.6917, 13.3478, 12.6919, 13.3477, 12.9212, 12.8817, 12.921]}], 'confidence': 0.951, 'spans': [{'offset': 4383, 'length': 4}]},
#  'Box17z': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8844, 13.5252, 13.3477, 13.5262, 13.3472, 13.7556, 12.8839, 13.7545]}], 'confidence': 0.957, 'spans': [{'offset': 4433, 'length': 4}]},
#  'Box18': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.5118, 14.0252, 15.9708, 14.0253, 15.9707, 14.2556, 15.5117, 14.2555]}], 'confidence': 0.957, 'spans': [{'offset': 4496, 'length': 4}]},
#  'Box20': {'type': 'number', 'valueNumber': 0, 'content': '0.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [12.8797, 15.0271, 13.3477, 15.0265, 13.348, 15.2604, 12.88, 15.2611]}], 'confidence': 0.943, 'spans': [{'offset': 4633, 'length': 4}]},
#  'Box21': {'type': 'number', 'valueNumber': 763, 'content': '763.00', 'boundingRegions': [{'pageNumber': 2, 'polygon': [15.2633, 15.8577, 15.9709, 15.8584, 15.9707, 16.0911, 15.2631, 16.0904]}], 'confidence': 0.966, 'spans': [{'offset': 4792, 'length': 6}]}}
