# %% [markdown]
# ## Setup
#
# **Before running this notebook, ensure you have selected the correct Python kernel. If running in the `devcontainer` environment, this is likely to be 3.12.11 at `/usr/local/python/current/bin/python`.**
#
# ![Example devcontainer notebook kernel](../../../../images/python-notebook-kernel.png)

# %%
import sys
import os
from pathlib import Path
wdir = os.path.abspath('../../../../')
sys.path.append(os.path.join(wdir, 'samples/python/modules/')) # Import local modules

from IPython.display import display
import os
from dotenv import dotenv_values
import base64
import io
import json
import pandas as pd
from openai import AzureOpenAI
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeResult
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from concurrent.futures import ThreadPoolExecutor
from pdf2image import convert_from_bytes

from samples.app_settings import AppSettings
from samples.utils.stopwatch import Stopwatch

from samples.models.classification import Classifications
from samples.utils.document_intelligence_result_parser import parse_document_fields
from samples.utils.custom_json_encoder import CustomJsonEncoder
from samples.confidence.document_intelligence_confidence import evaluate_confidence as evaluate_di_confidence
from samples.evaluation.accuracy_evaluator import AccuracyEvaluator
from samples.evaluation.comparison import get_extraction_comparison

# %%
app_settings = AppSettings(dotenv_values(Path(os.path.join(wdir, '.env'))))
scenario_path = Path(os.path.join(wdir, 'samples/python/scenarios/us_tax/'))
scenario_name = "us-tax-1040-extraction"

# Configure the default credential for accessing Azure services using Azure CLI credentials
credential = DefaultAzureCredential(
    exclude_workload_identity_credential=True,
    exclude_developer_cli_credential=True,
    exclude_environment_credential=True,
    exclude_managed_identity_credential=True,
    exclude_powershell_credential=True,
    exclude_shared_token_cache_credential=True,
    exclude_interactive_browser_credential=True
)

openai_token_provider = get_bearer_token_provider(credential, 'https://cognitiveservices.azure.com/.default')

openai_client = AzureOpenAI(
    azure_endpoint=app_settings.azure_openai_endpoint,
    azure_ad_token_provider=openai_token_provider,
    api_version=app_settings.azure_openai_api_version
)

document_intelligence_client = DocumentIntelligenceClient(
    endpoint=app_settings.azure_ai_services_endpoint,
    credential=credential
)

# %%
inputs_path = Path(os.path.join(wdir, 'samples/assets/us_tax/'))
metadata_fname = "us-tax-1040.json" # Change this to the file you want to evaluate
metadata_fpath = Path(os.path.join(inputs_path, metadata_fname))

with open(metadata_fpath, 'r') as f:
    metadata = json.load(f)
    
expected_outputs = [
    metadata[key]
    for key in metadata.keys() if key.endswith('_expected')
]

pdf_fname = metadata['fname']
pdf_fpath = Path(os.path.join(inputs_path, pdf_fname))

evaluator = AccuracyEvaluator()

# %%
page_images = []

def encode_page(page):
    byte_io = io.BytesIO()
    page.save(byte_io, format='PNG')
    base64_data = base64.b64encode(byte_io.getvalue()).decode('utf-8')
    return {
        "type": "image_url",
        "image_url": {
            "url": f"data:image/png;base64,{base64_data}"
        }
    }

with Stopwatch() as image_stopwatch:
    with open(pdf_fpath, "rb") as f:
        document_bytes = f.read()

    pages = convert_from_bytes(document_bytes)
    
    # Process each page in parallel using multiple processes
    with ThreadPoolExecutor() as executor:
        results = list(executor.map(encode_page, pages))
        page_images.extend(results)

# %% [markdown]
# ## Classify

# %%
classifications = [
    {
        "classification": "US Tax Form 1040",
        "description": "A US individual income tax return form, used to report annual income tax return filed by citizens or residents of the United States.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule 1",
        "description": "A form used to report additional income and adjustments to income.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule 2",
        "description": "A form used to report additional taxes.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule 3",
        "description": "A form used to report nonrefundable credits.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule A",
        "description": "A form used to report itemized deductions for individual income tax returns.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule B",
        "description": "A form used to report interest and ordinary dividends.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule C",
        "description": "A form used to report income or loss from a business operated or a profession practiced as a sole proprietor.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule D",
        "description": "A form used to report capital gains and losses.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule E",
        "description": "A form used to report income or loss from rental real estate, royalties, partnerships, S corporations, estates, trusts, etc.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule EIC",
        "description": "A form used to claim the Earned Income Credit (EIC).",
    },
    {
        "classification": "US Tax Form 1040 - Schedule F",
        "description": "A form used to report profit or loss from farming.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule H",
        "description": "A form used to report household employment taxes.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule J",
        "description": "A form used to figure the tax on a qualified farmer's or fisherman's income.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule R",
        "description": "A form used to claim the Credit for the Elderly or the Disabled.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule SE",
        "description": "A form used to calculate self-employment tax.",
    },
    {
        "classification": "US Tax Form 1040 - Schedule 8812",
        "description": "A form used to claim the Child Tax Credit and Credit for Other Dependents.",
    }
]

# %%
classification_model_map = {
    "US Tax Form 1040": "prebuilt-tax.us.1040",
    "US Tax Form 1040 - Schedule 1": "prebuilt-tax.us.1040Schedule1",
    "US Tax Form 1040 - Schedule 2": "prebuilt-tax.us.1040Schedule2",
    "US Tax Form 1040 - Schedule 3": "prebuilt-tax.us.1040Schedule3",
    "US Tax Form 1040 - Schedule A": "prebuilt-tax.us.1040ScheduleA",
    "US Tax Form 1040 - Schedule B": "prebuilt-tax.us.1040ScheduleB",
    "US Tax Form 1040 - Schedule C": "prebuilt-tax.us.1040ScheduleC",
    "US Tax Form 1040 - Schedule D": "prebuilt-tax.us.1040ScheduleD",
    "US Tax Form 1040 - Schedule E": "prebuilt-tax.us.1040ScheduleE",
    "US Tax Form 1040 - Schedule EIC": "prebuilt-tax.us.1040ScheduleEIC",
    "US Tax Form 1040 - Schedule F": "prebuilt-tax.us.1040ScheduleF",
    "US Tax Form 1040 - Schedule H": "prebuilt-tax.us.1040ScheduleH",
    "US Tax Form 1040 - Schedule J": "prebuilt-tax.us.1040ScheduleJ",
    "US Tax Form 1040 - Schedule R": "prebuilt-tax.us.1040ScheduleR",
    "US Tax Form 1040 - Schedule SE": "prebuilt-tax.us.1040ScheduleSE",
    "US Tax Form 1040 - Schedule 8812": "prebuilt-tax.us.1040Schedule8812"
}

# %%
classify_system_prompt = f"""You are an AI assistant that helps detect the boundaries of sub-section or sub-documents using the provided classifications.

## Classifications

{json.dumps(classifications)}
"""

# %%
classify_user_content = []

# %%
classify_user_prompt = f"""Classify documents that are a US Tax Form in the provided page images.
- A single classification may span multiple page images.
- A single page image may contain multiple classifications.
- If a page image does not contain a classification, ignore it."""

classify_user_content.append({
    "type": "text",
    "text": classify_user_prompt
})

# for each of the page images, add a text content block with the page index, and then another block with the image
for i, page_image in enumerate(page_images):
    classify_user_content.append({
        "type": "text",
        "text": f"Page {i + 1}:"
    })
    classify_user_content.append(page_image)

# %%
with Stopwatch() as classify_stopwatch:
    classify_completion = openai_client.beta.chat.completions.parse(
        model=app_settings.azure_openai_chat_deployment,
        messages=[
            {
                "role": "system",
                "content": classify_system_prompt,
            },
            {
                "role": "user",
                "content": classify_user_content
            }
        ],
        response_format=Classifications,
        max_tokens=4096,
        temperature=0.1,
        top_p=0.1,
        logprobs=True # Enabled to determine the confidence of the response.
    )

# %%
document_classifications = classify_completion.choices[0].message.parsed

# %%
# DEBUG: Display the document classifications
print(document_classifications.model_dump_json(indent=2))
# Out:
# {
#   "classifications": [
#     {
#       "classification": "US Tax Form 1040",
#       "image_range_start": 1,
#       "image_range_end": 2
#     },
#     {
#       "classification": "US Tax Form 1040 - Schedule 1",
#       "image_range_start": 3,
#       "image_range_end": 4
#     },
#     {
#       "classification": "US Tax Form 1040 - Schedule 2",
#       "image_range_start": 5,
#       "image_range_end": 6
#     }
#   ]
# }

# %%
# For each document classification, group the page images together
classified_images = []
classified_images_pil = []

for classification in document_classifications.classifications:
    image_range_start = classification.image_range_start
    image_range_end = classification.image_range_end

    classified_images.append(page_images[image_range_start - 1:image_range_end])
    classified_images_pil.append(pages[image_range_start - 1:image_range_end])

# %% [markdown]
# ## Extract

# %%
for i, images in enumerate(classified_images):
    classification = document_classifications.classifications[i]
    
    display(f"Classification {i} - {classification.classification}")
    
    images_pil = classified_images_pil[i]
    
    pdf_bytes = io.BytesIO()
    images_pil[0].save(pdf_bytes, format='PDF', resolution=100.0, save_all=True, append_images=images_pil[1:])
    pdf_bytes.seek(0)
    
    # DEBUG: Save the PDF to a temporary file
    pdf_fpath = Path(os.path.join(scenario_path, f"{pdf_fname}_{classification.classification}.pdf"))
    with open(pdf_fpath, "wb") as f:
        f.write(pdf_bytes.read())
    pdf_bytes.seek(0)
    
    # Use the classification of the document to determine the Azure AI Document Intelligence model to use
    model_id = classification_model_map[classification.classification]
        
    with Stopwatch() as di_stopwatch:
        poller = document_intelligence_client.begin_analyze_document(
            model_id=model_id,
            body=pdf_bytes,
            content_type="application/pdf"
        )
        
        result: AnalyzeResult = poller.result()

        doc_result = result.documents[0].fields
            
    doc_result_dict = parse_document_fields(doc_result)
    expected_dict = expected_outputs[i] if i < len(expected_outputs) else None
    
    # DEBUG: Display the document intelligence content
    doc_result_json = json.dumps(doc_result_dict, indent=2)
    print(doc_result_json)
    
    if expected_dict is not None:
        accuracy = evaluator.evaluate(expected=expected_dict, actual=doc_result_dict)
    else:
        accuracy = None

    confidence = evaluate_di_confidence(doc_result_dict, result)
    
    # DEBUG: Gets the total execution time of the data extraction process.
    total_elapsed = classify_stopwatch.elapsed + di_stopwatch.elapsed + image_stopwatch.elapsed
        
    # DEBUG: Save both the original doc_result and the parsed doc_result to a file
    di_result_fpath = Path(os.path.join(scenario_path, f"{pdf_fname}_{classification.classification}_original.json"))
    with open(di_result_fpath, "w") as f:
        json.dump(doc_result, f, indent=2, cls=CustomJsonEncoder)
        
    di_result_parsed_fpath = Path(os.path.join(scenario_path, f"{pdf_fname}_{classification.classification}_parsed.json"))
    with open(di_result_parsed_fpath, "w") as f:
        json.dump(parse_document_fields(doc_result), f, indent=2)
        
    display_accuracy = f"{accuracy['overall'] * 100:.2f}%" if accuracy is not None else "N/A"
    
    # DEBUG: Display the outputs of the data extraction process.
    df = pd.DataFrame([
        {
            "Document": pdf_fname,
            "Index": i,
            "Accuracy": display_accuracy,
            "Confidence": f"{confidence['_overall'] * 100:.2f}%",
            "Execution Time": f"{total_elapsed:.2f} seconds",
            "Classify Execution Time": f"{classify_stopwatch.elapsed:.2f} seconds",
            "Document Intelligence Execution Time": f"{di_stopwatch.elapsed:.2f} seconds",
            "Image Pre-processing Execution Time": f"{image_stopwatch.elapsed:.2f} seconds"
        }
    ])

    display(df)
    
    if accuracy is not None:
        display(get_extraction_comparison(expected_dict, doc_result_dict, confidence, accuracy['accuracy']))
# Out:
# 'Classification 0 - US Tax Form 1040'
# {
#   "TaxYear": "2024",
#   "Taxpayer": {
#     "SSN": "400-12-3456",
#     "LastName": "Sample",
#     "FirstNameAndInitials": "John Q.",
#     "Address": {
#       "houseNumber": "123",
#       "road": "Maple Drive",
#       "postalCode": "62704",
#       "city": "Springfield",
#       "state": "IL",
#       "streetAddress": "123 Maple Drive"
#     },
#     "ForeignCountryName": "",
#     "ForeignProvinceStateOrCounty": "",
#     "ForeignPostalCode": ""
#   },
#   "Spouse": {
#     "SSN": "400-65-4321",
#     "LastName": "Sample",
#     "FirstNameAndInitials": "Jane Q."
#   },
#   "Dependents": [
#     {
#       "Name": "Jack Sample",
#       "SSN": "400-00-0001",
#       "RelationshipToFiler": "Son",
#       "CreditType": [
#         "ChildTaxCredit"
#       ]
#     },
#     {
#       "Name": "Jill Sample",
#       "SSN": "400-00-0002",
#       "RelationshipToFiler": "Daughter",
#       "CreditType": [
#         "ChildTaxCredit"
#       ]
#     },
#     {
#       "Name": "",
#       "SSN": "",
#       "RelationshipToFiler": "",
#       "CreditType": []
#     },
#     {
#       "Name": "",
#       "SSN": "",
#       "RelationshipToFiler": "",
#       "CreditType": []
#     }
#   ],
#   "ThirdPartyDesignee": {
#     "PhoneNumber": "",
#     "Name": "",
#     "PersonalIdentificationNumber": ""
#   },
#   "SignatureDetails": {
#     "TaxpayerOccupation": "Engineer",
#     "TaxpayerPIN": "492132",
#     "TaxpayerPhoneNumber": "",
#     "TaxpayerEmail": "",
#     "SpouseOccupation": "Engineer",
#     "SpousePIN": "482712"
#   },
#   "PaidPreparer": {
#     "PreparerName": "",
#     "PreparerPTIN": "",
#     "IsPreparerSelfEmployed": false,
#     "PreparerFirmName": "",
#     "PreparerFirmPhoneNumber": "",
#     "PreparerFirmAddress": "",
#     "PreparerFirmEIN": ""
#   },
#   "FilingStatus": [
#     "MarriedFillingSeparately"
#   ],
#   "NameOfSpouseOrQualifyingPerson": "Jane Q. Sample",
#   "PresidentialElectionCampaign": [],
#   "DigitalAssets": [],
#   "ClaimStatus": [],
#   "TaxpayerAgeBlindeness": [
#     "Above64"
#   ],
#   "SpouseAgeBlindeness": [
#     "Above64"
#   ],
#   "MoreThanFourDependents": false,
#   "Box1a": 154070,
#   "Box1b": "",
#   "Box1c": "",
#   "Box1d": "",
#   "Box1e": "",
#   "Box1f": "",
#   "Box1g": "",
#   "Box1h": "",
#   "Box1i": "",
#   "Box1z": "",
#   "Box2a": "",
#   "Box2b": 350,
#   "Box3a": 600,
#   "Box3b": 820,
#   "Box4a": "",
#   "Box4b": "",
#   "Box5a": "",
#   "Box5b": "",
#   "Box6a": "",
#   "Box6b": "",
#   "Box6cCheckbox": false,
#   "Box7Checkbox": false,
#   "Box7": 6300,
#   "Box8": 5400,
#   "Box9": 166940,
#   "Box10": 10232,
#   "Box11": 156708,
#   "Box12": 29200,
#   "Box13": "",
#   "Box14": 29200,
#   "Box15": 127508,
#   "Box16FromForm": [],
#   "Box16OtherFormNumber": "",
#   "Box16": 18667,
#   "Box17": 0,
#   "Box18": 18667,
#   "Box19": 4000,
#   "Box20": 0,
#   "Box21": 4000,
#   "Box22": 14667,
#   "Box23": 763,
#   "Box24": 15430,
#   "Box25a": 19000,
#   "Box25b": 0,
#   "Box25c": 0,
#   "Box25d": 19000,
#   "Box26": 0,
#   "Box27": "",
#   "Box28": "",
#   "Box29": "",
#   "Box31": "",
#   "Box32": "",
#   "Box33": 19000,
#   "Box34": 3570,
#   "Box35Checkbox": false,
#   "Box35a": 3570,
#   "Box35b": "",
#   "Box35c": [],
#   "Box35d": "",
#   "Box36": "",
#   "Box37": "",
#   "Box38": "",
#   "HasAssignedThirdPartyDesignee": [
#     "No"
#   ]
# }
#           Document  Index Accuracy Confidence Execution Time  \
# 0  us-tax-1040.pdf      0  100.00%     92.36%  18.15 seconds
#
#   Classify Execution Time Document Intelligence Execution Time  \
# 0            6.34 seconds                        10.98 seconds
#
#   Image Pre-processing Execution Time
# 0                        0.83 seconds
# <style type="text/css">
# #T_9bfc9_row0_col0, #T_9bfc9_row0_col1, #T_9bfc9_row0_col2, #T_9bfc9_row0_col3, #T_9bfc9_row0_col4, #T_9bfc9_row1_col0, #T_9bfc9_row1_col1, #T_9bfc9_row1_col2, #T_9bfc9_row1_col3, #T_9bfc9_row1_col4, #T_9bfc9_row2_col0, #T_9bfc9_row2_col1, #T_9bfc9_row2_col2, #T_9bfc9_row2_col3, #T_9bfc9_row2_col4, #T_9bfc9_row3_col0, #T_9bfc9_row3_col1, #T_9bfc9_row3_col2, #T_9bfc9_row3_col3, #T_9bfc9_row3_col4, #T_9bfc9_row4_col0, #T_9bfc9_row4_col1, #T_9bfc9_row4_col2, #T_9bfc9_row4_col3, #T_9bfc9_row4_col4, #T_9bfc9_row5_col0, #T_9bfc9_row5_col1, #T_9bfc9_row5_col2, #T_9bfc9_row5_col3, #T_9bfc9_row5_col4, #T_9bfc9_row6_col0, #T_9bfc9_row6_col1, #T_9bfc9_row6_col2, #T_9bfc9_row6_col3, #T_9bfc9_row6_col4, #T_9bfc9_row7_col0, #T_9bfc9_row7_col1, #T_9bfc9_row7_col2, #T_9bfc9_row7_col3, #T_9bfc9_row7_col4, #T_9bfc9_row8_col0, #T_9bfc9_row8_col1, #T_9bfc9_row8_col2, #T_9bfc9_row8_col3, #T_9bfc9_row8_col4, #T_9bfc9_row9_col0, #T_9bfc9_row9_col1, #T_9bfc9_row9_col2, #T_9bfc9_row9_col3, #T_9bfc9_row9_col4, #T_9bfc9_row10_col0, #T_9bfc9_row10_col1, #T_9bfc9_row10_col2, #T_9bfc9_row10_col3, #T_9bfc9_row10_col4, #T_9bfc9_row11_col0, #T_9bfc9_row11_col1, #T_9bfc9_row11_col2, #T_9bfc9_row11_col3, #T_9bfc9_row11_col4, #T_9bfc9_row12_col0, #T_9bfc9_row12_col1, #T_9bfc9_row12_col2, #T_9bfc9_row12_col3, #T_9bfc9_row12_col4, #T_9bfc9_row13_col0, #T_9bfc9_row13_col1, #T_9bfc9_row13_col2, #T_9bfc9_row13_col3, #T_9bfc9_row13_col4, #T_9bfc9_row14_col0, #T_9bfc9_row14_col1, #T_9bfc9_row14_col2, #T_9bfc9_row14_col3, #T_9bfc9_row14_col4, #T_9bfc9_row15_col0, #T_9bfc9_row15_col1, #T_9bfc9_row15_col2, #T_9bfc9_row15_col3, #T_9bfc9_row15_col4, #T_9bfc9_row16_col0, #T_9bfc9_row16_col1, #T_9bfc9_row16_col2, #T_9bfc9_row16_col3, #T_9bfc9_row16_col4, #T_9bfc9_row17_col0, #T_9bfc9_row17_col1, #T_9bfc9_row17_col2, #T_9bfc9_row17_col3, #T_9bfc9_row17_col4, #T_9bfc9_row18_col0, #T_9bfc9_row18_col1, #T_9bfc9_row18_col2, #T_9bfc9_row18_col3, #T_9bfc9_row18_col4, #T_9bfc9_row19_col0, #T_9bfc9_row19_col1, #T_9bfc9_row19_col2, #T_9bfc9_row19_col3, #T_9bfc9_row19_col4, #T_9bfc9_row20_col0, #T_9bfc9_row20_col1, #T_9bfc9_row20_col2, #T_9bfc9_row20_col3, #T_9bfc9_row20_col4, #T_9bfc9_row21_col0, #T_9bfc9_row21_col1, #T_9bfc9_row21_col2, #T_9bfc9_row21_col3, #T_9bfc9_row21_col4, #T_9bfc9_row22_col0, #T_9bfc9_row22_col1, #T_9bfc9_row22_col2, #T_9bfc9_row22_col3, #T_9bfc9_row22_col4, #T_9bfc9_row23_col0, #T_9bfc9_row23_col1, #T_9bfc9_row23_col2, #T_9bfc9_row23_col3, #T_9bfc9_row23_col4, #T_9bfc9_row24_col0, #T_9bfc9_row24_col1, #T_9bfc9_row24_col2, #T_9bfc9_row24_col3, #T_9bfc9_row24_col4, #T_9bfc9_row25_col0, #T_9bfc9_row25_col1, #T_9bfc9_row25_col2, #T_9bfc9_row25_col3, #T_9bfc9_row25_col4, #T_9bfc9_row26_col0, #T_9bfc9_row26_col1, #T_9bfc9_row26_col2, #T_9bfc9_row26_col3, #T_9bfc9_row26_col4, #T_9bfc9_row27_col0, #T_9bfc9_row27_col1, #T_9bfc9_row27_col2, #T_9bfc9_row27_col3, #T_9bfc9_row27_col4, #T_9bfc9_row28_col0, #T_9bfc9_row28_col1, #T_9bfc9_row28_col2, #T_9bfc9_row28_col3, #T_9bfc9_row28_col4, #T_9bfc9_row29_col0, #T_9bfc9_row29_col1, #T_9bfc9_row29_col2, #T_9bfc9_row29_col3, #T_9bfc9_row29_col4, #T_9bfc9_row30_col0, #T_9bfc9_row30_col1, #T_9bfc9_row30_col2, #T_9bfc9_row30_col3, #T_9bfc9_row30_col4, #T_9bfc9_row31_col0, #T_9bfc9_row31_col1, #T_9bfc9_row31_col2, #T_9bfc9_row31_col3, #T_9bfc9_row31_col4, #T_9bfc9_row32_col0, #T_9bfc9_row32_col1, #T_9bfc9_row32_col2, #T_9bfc9_row32_col3, #T_9bfc9_row32_col4, #T_9bfc9_row33_col0, #T_9bfc9_row33_col1, #T_9bfc9_row33_col2, #T_9bfc9_row33_col3, #T_9bfc9_row33_col4, #T_9bfc9_row34_col0, #T_9bfc9_row34_col1, #T_9bfc9_row34_col2, #T_9bfc9_row34_col3, #T_9bfc9_row34_col4, #T_9bfc9_row35_col0, #T_9bfc9_row35_col1, #T_9bfc9_row35_col2, #T_9bfc9_row35_col3, #T_9bfc9_row35_col4, #T_9bfc9_row36_col0, #T_9bfc9_row36_col1, #T_9bfc9_row36_col2, #T_9bfc9_row36_col3, #T_9bfc9_row36_col4, #T_9bfc9_row37_col0, #T_9bfc9_row37_col1, #T_9bfc9_row37_col2, #T_9bfc9_row37_col3, #T_9bfc9_row37_col4, #T_9bfc9_row38_col0, #T_9bfc9_row38_col1, #T_9bfc9_row38_col ...
# 'Classification 1 - US Tax Form 1040 - Schedule 1'
# {
#   "TaxYear": "2024",
#   "Taxpayer": {
#     "SSN": "400-12-3456",
#     "Name": "John Q. Sample"
#   },
#   "Box1": 0,
#   "Box2a": 0,
#   "Box2b": "",
#   "Box3": 5400,
#   "Box4": 0,
#   "Box5": 0,
#   "Box6": 0,
#   "Box7": 0,
#   "Box8a": 0,
#   "Box8b": 0,
#   "Box8c": 0,
#   "Box8d": 0,
#   "Box8e": 0,
#   "Box8f": 0,
#   "Box8g": 0,
#   "Box8h": 0,
#   "Box8i": 0,
#   "Box8j": 0,
#   "Box8k": 0,
#   "Box8l": 0,
#   "Box8m": 0,
#   "Box8n": 0,
#   "Box8o": 0,
#   "Box8p": 0,
#   "Box8q": 0,
#   "Box8r": 0,
#   "Box8s": 0,
#   "Box8t": 0,
#   "Box8u": 0,
#   "Box8z": 0,
#   "Box9": 0,
#   "Box10": 5400,
#   "Box11": 0,
#   "Box12": 0,
#   "Box13": 3850,
#   "Box14": 0,
#   "Box15": 382,
#   "Box16": 0,
#   "Box17": 0,
#   "Box18": 0,
#   "Box19a": 0,
#   "Box19b": "",
#   "Box19c": "",
#   "Box20": 6000,
#   "Box21": 0,
#   "Box23": 0,
#   "Box24a": 0,
#   "Box24b": 0,
#   "Box24d": 0,
#   "Box24e": 0,
#   "Box24f": 0,
#   "Box24g": 0,
#   "Box24h": 0,
#   "Box24i": 0,
#   "Box24j": 0,
#   "Box24k": 0,
#   "Box24z": 0,
#   "Box25": 10232,
#   "Box26": 0
# }
#           Document  Index Accuracy Confidence Execution Time  \
# 0  us-tax-1040.pdf      1   98.97%     98.20%  13.84 seconds
#
#   Classify Execution Time Document Intelligence Execution Time  \
# 0            6.34 seconds                         6.67 seconds
#
#   Image Pre-processing Execution Time
# 0                        0.83 seconds
# <style type="text/css">
# #T_66a23_row0_col0, #T_66a23_row0_col1, #T_66a23_row0_col2, #T_66a23_row0_col3, #T_66a23_row0_col4, #T_66a23_row1_col0, #T_66a23_row1_col1, #T_66a23_row1_col2, #T_66a23_row1_col3, #T_66a23_row1_col4, #T_66a23_row2_col0, #T_66a23_row2_col1, #T_66a23_row2_col2, #T_66a23_row2_col3, #T_66a23_row2_col4, #T_66a23_row3_col0, #T_66a23_row3_col1, #T_66a23_row3_col2, #T_66a23_row3_col3, #T_66a23_row3_col4, #T_66a23_row4_col0, #T_66a23_row4_col1, #T_66a23_row4_col2, #T_66a23_row4_col3, #T_66a23_row4_col4, #T_66a23_row5_col0, #T_66a23_row5_col1, #T_66a23_row5_col2, #T_66a23_row5_col3, #T_66a23_row5_col4, #T_66a23_row6_col0, #T_66a23_row6_col1, #T_66a23_row6_col2, #T_66a23_row6_col3, #T_66a23_row6_col4, #T_66a23_row7_col0, #T_66a23_row7_col1, #T_66a23_row7_col2, #T_66a23_row7_col3, #T_66a23_row7_col4, #T_66a23_row8_col0, #T_66a23_row8_col1, #T_66a23_row8_col2, #T_66a23_row8_col3, #T_66a23_row8_col4, #T_66a23_row9_col0, #T_66a23_row9_col1, #T_66a23_row9_col2, #T_66a23_row9_col3, #T_66a23_row9_col4, #T_66a23_row10_col0, #T_66a23_row10_col1, #T_66a23_row10_col2, #T_66a23_row10_col3, #T_66a23_row10_col4, #T_66a23_row11_col0, #T_66a23_row11_col1, #T_66a23_row11_col2, #T_66a23_row11_col3, #T_66a23_row11_col4, #T_66a23_row12_col0, #T_66a23_row12_col1, #T_66a23_row12_col2, #T_66a23_row12_col3, #T_66a23_row12_col4, #T_66a23_row13_col0, #T_66a23_row13_col1, #T_66a23_row13_col2, #T_66a23_row13_col3, #T_66a23_row13_col4, #T_66a23_row14_col0, #T_66a23_row14_col1, #T_66a23_row14_col2, #T_66a23_row14_col3, #T_66a23_row14_col4, #T_66a23_row15_col0, #T_66a23_row15_col1, #T_66a23_row15_col2, #T_66a23_row15_col3, #T_66a23_row15_col4, #T_66a23_row16_col0, #T_66a23_row16_col1, #T_66a23_row16_col2, #T_66a23_row16_col3, #T_66a23_row16_col4, #T_66a23_row17_col0, #T_66a23_row17_col1, #T_66a23_row17_col2, #T_66a23_row17_col3, #T_66a23_row17_col4, #T_66a23_row18_col0, #T_66a23_row18_col1, #T_66a23_row18_col2, #T_66a23_row18_col3, #T_66a23_row18_col4, #T_66a23_row19_col0, #T_66a23_row19_col1, #T_66a23_row19_col2, #T_66a23_row19_col3, #T_66a23_row19_col4, #T_66a23_row20_col0, #T_66a23_row20_col1, #T_66a23_row20_col2, #T_66a23_row20_col3, #T_66a23_row20_col4, #T_66a23_row21_col0, #T_66a23_row21_col1, #T_66a23_row21_col2, #T_66a23_row21_col3, #T_66a23_row21_col4, #T_66a23_row22_col0, #T_66a23_row22_col1, #T_66a23_row22_col2, #T_66a23_row22_col3, #T_66a23_row22_col4, #T_66a23_row23_col0, #T_66a23_row23_col1, #T_66a23_row23_col2, #T_66a23_row23_col3, #T_66a23_row23_col4, #T_66a23_row24_col0, #T_66a23_row24_col1, #T_66a23_row24_col2, #T_66a23_row24_col3, #T_66a23_row24_col4, #T_66a23_row25_col0, #T_66a23_row25_col1, #T_66a23_row25_col2, #T_66a23_row25_col3, #T_66a23_row25_col4, #T_66a23_row26_col0, #T_66a23_row26_col1, #T_66a23_row26_col2, #T_66a23_row26_col3, #T_66a23_row26_col4, #T_66a23_row29_col0, #T_66a23_row29_col1, #T_66a23_row29_col2, #T_66a23_row29_col3, #T_66a23_row29_col4, #T_66a23_row30_col0, #T_66a23_row30_col1, #T_66a23_row30_col2, #T_66a23_row30_col3, #T_66a23_row30_col4, #T_66a23_row31_col0, #T_66a23_row31_col1, #T_66a23_row31_col2, #T_66a23_row31_col3, #T_66a23_row31_col4, #T_66a23_row32_col0, #T_66a23_row32_col1, #T_66a23_row32_col2, #T_66a23_row32_col3, #T_66a23_row32_col4, #T_66a23_row33_col0, #T_66a23_row33_col1, #T_66a23_row33_col2, #T_66a23_row33_col3, #T_66a23_row33_col4, #T_66a23_row34_col0, #T_66a23_row34_col1, #T_66a23_row34_col2, #T_66a23_row34_col3, #T_66a23_row34_col4, #T_66a23_row35_col0, #T_66a23_row35_col1, #T_66a23_row35_col2, #T_66a23_row35_col3, #T_66a23_row35_col4, #T_66a23_row36_col0, #T_66a23_row36_col1, #T_66a23_row36_col2, #T_66a23_row36_col3, #T_66a23_row36_col4, #T_66a23_row37_col0, #T_66a23_row37_col1, #T_66a23_row37_col2, #T_66a23_row37_col3, #T_66a23_row37_col4, #T_66a23_row38_col0, #T_66a23_row38_col1, #T_66a23_row38_col2, #T_66a23_row38_col3, #T_66a23_row38_col4, #T_66a23_row39_col0, #T_66a23_row39_col1, #T_66a23_row39_col2, #T_66a23_row39_col3, #T_66a23_row39_col4, #T_66a23_row40_col0, #T_66a23_row40_col1, #T_66a23_row40_col ...
#   background-color: #66ff33;
# }
# #T_66a23_row27_col0, #T_66a23_row27_col1, #T_66a23_row27_col2, #T_66a23_row27_col3, #T_66a23_row27_col4, #T_66a23_row28_col0, #T_66a23_row28_col1, #T_66a23_row28_col2, #T_66a23_row28_col3, #T_66a23_row28_col4 {
#   background-color: #ff9999;
# }
# </style>
# <table id="T_66a23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66a23_level0_col0" class="col_heading level0 col0" >Field</th>
#       <th id="T_66a23_level0_col1" class="col_heading level0 col1" >Expected</th>
#       <th id="T_66a23_level0_col2" class="col_heading level0 col2" >Extracted</th>
#       <th id="T_66a23_level0_col3" class="col_heading level0 col3" >Confidence</th>
#       <th id="T_66a23_level0_col4" class="col_heading level0 col4" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66a23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66a23_row0_col0" class="data row0 col0" >Box1</td>
#       <td id="T_66a23_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_66a23_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_66a23_row0_col3" class="data row0 col3" >N/A</td>
#       <td id="T_66a23_row0_col4" class="data row0 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_66a23_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66a23_row1_col0" class="data row1 col0" >Box10</td>
#       <td id="T_66a23_row1_col1" class="data row1 col1" >5400</td>
#       <td id="T_66a23_row1_col2" class="data row1 col2" >5400</td>
#       <td id="T_66a23_row1_col3" class="data row1 col3" >N/A</td>
#       <td id="T_66a23_row1_col4" class="data row1 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_66a23_level0_row2" class="row_heading le
# 'Classification 2 - US Tax Form 1040 - Schedule 2'
# {
#   "TaxYear": "2024",
#   "Taxpayer": {
#     "SSN": "400-12-3456",
#     "Name": "John Q. Sample"
#   },
#   "Box1": "",
#   "Box2": 0,
#   "Box3": 0,
#   "Box4": 763,
#   "Box5": 0,
#   "Box6": 0,
#   "Box7": 0,
#   "Box8Checkbox": false,
#   "Box8": 0,
#   "Box9": 0,
#   "Box10": 0,
#   "Box11": 0,
#   "Box12": 0,
#   "Box13": 0,
#   "Box14": 0,
#   "Box15": 0,
#   "Box16": 0,
#   "Box17aExtraInfo": "",
#   "Box17a": 0,
#   "Box17b": 0,
#   "Box17c": 0,
#   "Box17d": 0,
#   "Box17e": 0,
#   "Box17f": 0,
#   "Box17g": 0,
#   "Box17h": 0,
#   "Box17i": 0,
#   "Box17j": 0,
#   "Box17k": 0,
#   "Box17l": 0,
#   "Box17m": 0,
#   "Box17n": 0,
#   "Box17o": 0,
#   "Box17p": 0,
#   "Box17q": 0,
#   "Box17z": 0,
#   "Box18": 0,
#   "Box20": 0,
#   "Box21": 763
# }
#           Document  Index Accuracy Confidence Execution Time  \
# 0  us-tax-1040.pdf      2   99.15%     98.95%  17.40 seconds
#
#   Classify Execution Time Document Intelligence Execution Time  \
# 0            6.34 seconds                        10.23 seconds
#
#   Image Pre-processing Execution Time
# 0                        0.83 seconds
# <style type="text/css">
# #T_ac23b_row0_col0, #T_ac23b_row0_col1, #T_ac23b_row0_col2, #T_ac23b_row0_col3, #T_ac23b_row0_col4, #T_ac23b_row1_col0, #T_ac23b_row1_col1, #T_ac23b_row1_col2, #T_ac23b_row1_col3, #T_ac23b_row1_col4, #T_ac23b_row2_col0, #T_ac23b_row2_col1, #T_ac23b_row2_col2, #T_ac23b_row2_col3, #T_ac23b_row2_col4, #T_ac23b_row3_col0, #T_ac23b_row3_col1, #T_ac23b_row3_col2, #T_ac23b_row3_col3, #T_ac23b_row3_col4, #T_ac23b_row4_col0, #T_ac23b_row4_col1, #T_ac23b_row4_col2, #T_ac23b_row4_col3, #T_ac23b_row4_col4, #T_ac23b_row5_col0, #T_ac23b_row5_col1, #T_ac23b_row5_col2, #T_ac23b_row5_col3, #T_ac23b_row5_col4, #T_ac23b_row6_col0, #T_ac23b_row6_col1, #T_ac23b_row6_col2, #T_ac23b_row6_col3, #T_ac23b_row6_col4, #T_ac23b_row7_col0, #T_ac23b_row7_col1, #T_ac23b_row7_col2, #T_ac23b_row7_col3, #T_ac23b_row7_col4, #T_ac23b_row8_col0, #T_ac23b_row8_col1, #T_ac23b_row8_col2, #T_ac23b_row8_col3, #T_ac23b_row8_col4, #T_ac23b_row9_col0, #T_ac23b_row9_col1, #T_ac23b_row9_col2, #T_ac23b_row9_col3, #T_ac23b_row9_col4, #T_ac23b_row10_col0, #T_ac23b_row10_col1, #T_ac23b_row10_col2, #T_ac23b_row10_col3, #T_ac23b_row10_col4, #T_ac23b_row11_col0, #T_ac23b_row11_col1, #T_ac23b_row11_col2, #T_ac23b_row11_col3, #T_ac23b_row11_col4, #T_ac23b_row12_col0, #T_ac23b_row12_col1, #T_ac23b_row12_col2, #T_ac23b_row12_col3, #T_ac23b_row12_col4, #T_ac23b_row13_col0, #T_ac23b_row13_col1, #T_ac23b_row13_col2, #T_ac23b_row13_col3, #T_ac23b_row13_col4, #T_ac23b_row14_col0, #T_ac23b_row14_col1, #T_ac23b_row14_col2, #T_ac23b_row14_col3, #T_ac23b_row14_col4, #T_ac23b_row15_col0, #T_ac23b_row15_col1, #T_ac23b_row15_col2, #T_ac23b_row15_col3, #T_ac23b_row15_col4, #T_ac23b_row16_col0, #T_ac23b_row16_col1, #T_ac23b_row16_col2, #T_ac23b_row16_col3, #T_ac23b_row16_col4, #T_ac23b_row17_col0, #T_ac23b_row17_col1, #T_ac23b_row17_col2, #T_ac23b_row17_col3, #T_ac23b_row17_col4, #T_ac23b_row18_col0, #T_ac23b_row18_col1, #T_ac23b_row18_col2, #T_ac23b_row18_col3, #T_ac23b_row18_col4, #T_ac23b_row19_col0, #T_ac23b_row19_col1, #T_ac23b_row19_col2, #T_ac23b_row19_col3, #T_ac23b_row19_col4, #T_ac23b_row20_col0, #T_ac23b_row20_col1, #T_ac23b_row20_col2, #T_ac23b_row20_col3, #T_ac23b_row20_col4, #T_ac23b_row21_col0, #T_ac23b_row21_col1, #T_ac23b_row21_col2, #T_ac23b_row21_col3, #T_ac23b_row21_col4, #T_ac23b_row22_col0, #T_ac23b_row22_col1, #T_ac23b_row22_col2, #T_ac23b_row22_col3, #T_ac23b_row22_col4, #T_ac23b_row23_col0, #T_ac23b_row23_col1, #T_ac23b_row23_col2, #T_ac23b_row23_col3, #T_ac23b_row23_col4, #T_ac23b_row24_col0, #T_ac23b_row24_col1, #T_ac23b_row24_col2, #T_ac23b_row24_col3, #T_ac23b_row24_col4, #T_ac23b_row25_col0, #T_ac23b_row25_col1, #T_ac23b_row25_col2, #T_ac23b_row25_col3, #T_ac23b_row25_col4, #T_ac23b_row26_col0, #T_ac23b_row26_col1, #T_ac23b_row26_col2, #T_ac23b_row26_col3, #T_ac23b_row26_col4, #T_ac23b_row27_col0, #T_ac23b_row27_col1, #T_ac23b_row27_col2, #T_ac23b_row27_col3, #T_ac23b_row27_col4, #T_ac23b_row28_col0, #T_ac23b_row28_col1, #T_ac23b_row28_col2, #T_ac23b_row28_col3, #T_ac23b_row28_col4, #T_ac23b_row29_col0, #T_ac23b_row29_col1, #T_ac23b_row29_col2, #T_ac23b_row29_col3, #T_ac23b_row29_col4, #T_ac23b_row30_col0, #T_ac23b_row30_col1, #T_ac23b_row30_col2, #T_ac23b_row30_col3, #T_ac23b_row30_col4, #T_ac23b_row31_col0, #T_ac23b_row31_col1, #T_ac23b_row31_col2, #T_ac23b_row31_col3, #T_ac23b_row31_col4, #T_ac23b_row32_col0, #T_ac23b_row32_col1, #T_ac23b_row32_col2, #T_ac23b_row32_col3, #T_ac23b_row32_col4, #T_ac23b_row33_col0, #T_ac23b_row33_col1, #T_ac23b_row33_col2, #T_ac23b_row33_col3, #T_ac23b_row33_col4, #T_ac23b_row34_col0, #T_ac23b_row34_col1, #T_ac23b_row34_col2, #T_ac23b_row34_col3, #T_ac23b_row34_col4, #T_ac23b_row35_col0, #T_ac23b_row35_col1, #T_ac23b_row35_col2, #T_ac23b_row35_col3, #T_ac23b_row35_col4, #T_ac23b_row36_col0, #T_ac23b_row36_col1, #T_ac23b_row36_col2, #T_ac23b_row36_col3, #T_ac23b_row36_col4, #T_ac23b_row37_col0, #T_ac23b_row37_col1, #T_ac23b_row37_col2, #T_ac23b_row37_col3, #T_ac23b_row37_col4, #T_ac23b_row38_col0, #T_ac23b_row38_col1, #T_ac23b_row38_col ...
#   background-color: #66ff33;
# }
# </style>
# <table id="T_ac23b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac23b_level0_col0" class="col_heading level0 col0" >Field</th>
#       <th id="T_ac23b_level0_col1" class="col_heading level0 col1" >Expected</th>
#       <th id="T_ac23b_level0_col2" class="col_heading level0 col2" >Extracted</th>
#       <th id="T_ac23b_level0_col3" class="col_heading level0 col3" >Confidence</th>
#       <th id="T_ac23b_level0_col4" class="col_heading level0 col4" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac23b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac23b_row0_col0" class="data row0 col0" >Box1</td>
#       <td id="T_ac23b_row0_col1" class="data row0 col1" ></td>
#       <td id="T_ac23b_row0_col2" class="data row0 col2" ></td>
#       <td id="T_ac23b_row0_col3" class="data row0 col3" >N/A</td>
#       <td id="T_ac23b_row0_col4" class="data row0 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_ac23b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac23b_row1_col0" class="data row1 col0" >Box10</td>
#       <td id="T_ac23b_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_ac23b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_ac23b_row1_col3" class="data row1 col3" >N/A</td>
#       <td id="T_ac23b_row1_col4" class="data row1 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_ac23b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac23b_row2_col0" class="data row2 col0" >Box11</td>
#       <td id="T_ac23b_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_ac23b_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_ac23b_row2_col3" class="data row2 col3" >N/A</td>
#       <td id="T_ac23b_row2_col4" class="data row2 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_ac23b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac23b_row3_col0" class="data row3 col0" >Box12</td>
#       <td id="T_ac23b_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_ac23b_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_ac23b_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_ac23b_row3_col4" class="data row3 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_ac23b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac23b_row4_col0" class="data row4 col0" >Box13</td>
#       <td id="T_ac23b_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_ac23b_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_ac23b_row4_col3" class="data row4 col3" >N/A</td>
#       <td id="T_ac23b_row4_col4" class="data row4 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_ac23b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ac23b_row5_col0" class="data row5 col0" >Box14</td>
#       <td id="T_ac23b_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_ac23b_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_ac23b_row5_col3" class="data row5 col3" >N/A</td>
#       <td id="T_ac23b_row5_col4" class="data row5 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_ac23b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ac23b_row6_col0" class="data row6 col0" >Box15</td>
#       <td id="T_ac23b_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_ac23b_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_ac23b_row6_col3" class="data row6 col3" >N/A</td>
#       <td id="T_ac23b_row6_col4" class="data row6 col4" >Match</td>
#     </tr>
#     <tr>
#       <th id="T_ac23b_level0_row7" class="row_heading level0 row7" >7</th>
